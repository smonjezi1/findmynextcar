# %%
import dill
#dill.dump(df, open('data_df.pkd', 'wb'))
df = dill.load(open('data_df.pkd', 'rb'))
#df.to_csv('table_a_h', sep=',', encoding='utf-8')

# %%
def price_fix(string):
    string=string.lstrip('$')
    return .95*(int(string))
df['Price'][0:len(df['Price'])]=list(map(price_fix, df['Price'][0:len(df['Price'])]))
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
import dill
data_dic2 = dill.load(open('data_dic2.pkd', 'rb'))

# %%
#df[['Name','model','year0','make0','model0','Price']][(df['make0'].isnull())&(df['year0']>2000)]

# %%
import pandas as pd
import numpy as np
import dill
#df = dill.load(open('pandas_df_a_h.pkd', 'rb'))
X = df.dropna(axis=0, subset=['year0', 'odometer', 'make0','model0','Price'])
X['Car']=X['make0']+','+X['model0']
#remove cars with low frequency
X=X[X.groupby('Car')['Car'].transform('count').ge(1000)]
X['year0'] = X['year0'].astype(int)
X['odometer'] = X['odometer'].astype(int)
X=X[X['year0']>1940][['year0','Car','odometer','Price','status']]
y = X[['Price']][:]
#X=np.asanyarray(X)
#y=np.asanyarray(y)
#X = pd.get_dummies(df=X)pd.get_dummies(s1, dummy_na=True)
#pd.isnull(X).sum() > 0

len(X)
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 666288

# %%
#no separation
import pandas as pd
import numpy as np
import dill
#df = dill.load(open('pandas_df_a_h.pkd', 'rb'))
X3 = df.dropna(axis=0, subset=['year0', 'odometer', 'make0','model0','Price'])
#remove cars with low frequency
X3=X3[[X3.groupby(['make0','model0'])[['make0','model0']].transform('count').ge(1000)][0]['make0']]
X3['year0'] = X3['year0'].astype(int)
X3['odometer'] = X3['odometer'].astype(int)
X3=X3[X3['year0']>1940][['year0','make0','model0','odometer','Price','status']]
y3 = X3[['Price']][:]
#X=np.asanyarray(X)
#y=np.asanyarray(y)
#X = pd.get_dummies(df=X)pd.get_dummies(s1, dummy_na=True)
#pd.isnull(X).sum() > 0

len(X3)
# Out:
# 666288

# %%
#X[['year0','Car','odometer','Price']][(X['status']=='clean')&(X['year0']>2000)].dropna().sort_values(['Price'], ascending=[0]).head()
X2=X[['year0','Car','odometer','Price']][(X['status']=='clean')&(X['year0']>2000)].dropna()
X2.dtypes
len(X2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d4a6206d0619> in <module>()
#       1 #X[['year0','Car','odometer','Price']][(X['status']=='clean')&(X['year0']>2000)].dropna().sort_values(['Price'], ascending=[0]).head()
# ----> 2 X2=X[['year0','Car','odometer','Price']][(X['status']=='clean')&(X['year0']>2000)].dropna()
#       3 X2.dtypes
#       4 len(X2)
#
# NameError: name 'X' is not defined

# %%
#X[['year0','Car','odometer','Price']][(X['status']=='clean')&(X['year0']>2000)].dropna().sort_values(['Price'], ascending=[0]).head()
X4=X3[['year0','make0','model0','odometer','Price']][(X3['status']=='clean')&(X3['year0']>2000)].dropna()
X4.dtypes
len(X4)
# Out:
# 593447

# %%
# data colelction and preprocessing
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv
# for data visualisation and statistical analysis
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set_style("white")
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline

# %%
#df.groupby(['make0', 'model0']).agg({'make0':'count'})
grouped = pd.pivot_table(X2, values=['year0'], index=['Car'],aggfunc=len).reset_index()
list_car=grouped['Car']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9eb9fafeda91> in <module>()
#       1 #df.groupby(['make0', 'model0']).agg({'make0':'count'})
# ----> 2 grouped = pd.pivot_table(X2, values=['year0'], index=['Car'],aggfunc=len).reset_index()
#       3 list_car=grouped['Car']
#
# NameError: name 'X2' is not defined

# %%
grouped2 = pd.pivot_table(X4, values=['year0'], index=['make0','model0'],aggfunc=len).reset_index()
#grouped2.sort_values(['year0'], ascending=[0]).head()

# %%
list_car2=grouped2['make0']+' '+grouped2['model0']
with open('top.txt', 'w') as f:
    for item in list_car2:
        f.write("%s\n" % item)

# %%
new_list=['Acura MDX', 'Acura TL', 'Acura TSX', 'Audi A4', 'Audi A6', 'Audi Q5', 'Audi Q7', 'BMW 3-series', 'BMW 3-series', 'BMW 3-series', 'BMW 3-series', 'BMW 5-series', 'BMW 5-series', 'BMW M3', 'BMW X3', 'BMW X5', 'Buick Enclave', 'Buick Encore', 'Buick LaCrosse', 'Cadillac ATS', 'Cadillac CTS', 'Cadillac DeVille', 'Cadillac Escalade', 'Cadillac Escalade-ESV', 'Cadillac SRX', 'Chevrolet Avalanche', 'Chevrolet Camaro', 'Chevrolet Cobalt', 'Chevrolet Colorado', 'Chevrolet Corvette', 'Chevrolet Cruze', 'Chevrolet Equinox', 'Chevrolet Express-Cargo', 'Chevrolet Impala', 'Chevrolet Malibu', 'Chevrolet Silverado-1500HD', 'Chevrolet Silverado-2500HD', 'Chevrolet Silverado-3500HD', 'Chevrolet Sonic', 'Chevrolet Suburban', 'Chevrolet Tahoe', 'Chevrolet TrailBlazer', 'Chevrolet Traverse', 'Chevrolet Volt', 'Chrysler 200', 'Chrysler 300', 'Chrysler 300', 'Chrysler PT Cruiser', 'Chrysler Sebring', 'Chrysler Town Country', 'Dodge Avenger', 'Dodge Challenger', 'Dodge Charger', 'Dodge Dakota', 'Dodge Dart', 'Dodge Durango', 'Dodge Grand Caravan', 'Dodge Journey', 'Ford Crown Victoria', 'Ford F-250-super-duty', 'Ford F-350-super-dutyFord Edge', 'Ford Edge', 'Ford Escape', 'Ford Expedition', 'Ford Explorer', 'Ford F-150', 'Ford F-250-super-duty', 'Ford F-350-super-duty', 'Ford F-450-super-duty', 'Ford Fiesta', 'Ford Flex', 'Ford Focus', 'Ford Fusion', 'Ford Mustang', 'Ford Ranger', 'Ford Taurus', 'Ford Transit Connect', 'GMC Sierra-1500', 'GMC Acadia', 'GMC Sierra-1500', 'GMC Sierra-2500', 'GMC Terrain', 'GMC Yukon', 'GMC Yukon-XL', 'Honda Accord', 'Honda CR-V', 'Honda Civic', 'Honda Fit', 'Honda Odyssey', 'Honda Pilot', 'Hyundai Accent', 'Hyundai Elantra', 'Hyundai Santa-Fe', 'Hyundai Santa-Fe', 'Hyundai Sonata', 'Hyundai Tucson', 'Hyundai Veloster', 'Lexus ES-350', 'Lexus ES-350', 'Lexus RX-350', 'Jeep Grand-Cherokee', 'Jeep Compass', 'Jeep Grand-Cherokee', 'Jeep Liberty', 'Jeep Patriot', 'Jeep Renegade', 'Jeep Wrangler', 'Jeep Wrangler', 'Kia Forte', 'Kia Optima', 'Kia Sedona', 'Kia Sorento', 'Kia Soul', 'Kia Sportage', 'Land-Rover Range-Rover', 'Land-Rover Range-Rover-Sport', 'Lexus ES-350', 'Lexus IS-350', 'Lexus RX-350', 'Lincoln MKX', 'Lincoln MKZ', 'Lincoln Town Car', 'Volkswagen Golf', 'Volkswagen Golf', 'Mazda CX-5-Miata', 'Mazda 3', 'Mazda 6', 'Mercedes-Benz C-Class', 'Mercedes-Benz C-Class', 'Mercedes-Benz E-Class', 'Mercedes-Benz GL', 'Mercedes-Benz ML', 'Mercedes-Benz S-Class', 'Lincoln Grand-Marquis', 'Nissan 370Z', 'Nissan Altima', 'Nissan Armada', 'Nissan Frontier', 'Nissan Maxima', 'Nissan Murano', 'Nissan Pathfinder', 'Nissan Rogue', 'Nissan Sentra', 'Nissan Titan', 'Nissan Versa', 'Nissan Pathfinder', 'Chevrolet Impala', 'Chevrolet Impala', 'Porsche 911', 'Porsche Cayenne', 'RAM 1500', 'RAM 2500', 'RAM 3500', 'Toyota Yaris', 'Subaru Forester', 'Subaru Impreza', 'Subaru Legacy', 'Subaru Outback', 'Toyota 4-Runner', 'Toyota Avalon', 'Toyota Camry', 'Toyota Corolla', 'Toyota FJ-Cruiser', 'Toyota Highlander', 'Toyota PRIUS', 'Toyota RAV4', 'Toyota Sequoia', 'Toyota Sienna', 'Toyota Tacoma', 'Toyota Tundra', 'Volkswagen Beetle', 'Volkswagen CC', 'Volkswagen GTI', 'Volkswagen Golf', 'Volkswagen Jetta', 'Volkswagen Jetta SportWagen', 'Volkswagen Passat', 'Volkswagen Tiguan', 'Volvo S60', 'Volvo XC90']
df_top=pd.DataFrame()
s=0
df_top['make0']=None
df_top['model0']=None
df_top['Car']=None
df_top['first_used']=None
for i in new_list:
    df_top.loc[s,'make0']=grouped2['make0'][s]
    df_top.loc[s,'model0']=grouped2['model0'][s] 
    df_top.loc[s,'Car']=grouped2['make0'][s]+','+grouped2['model0'][s]
    df_top.loc[s,'first_used']=i
    s+=1
#df_top

# %%
#trim X4
a=[[2001,2019],
[1996,2014],
[2004,2014],
[1996,2019],
[1998,2019],
[2009,2019],
[2007,2019],
[1984,2006],
[1996,2016],
[1996,2016],
[2007,2015],
[1985,2016],
[1986,2016],
[1988,2018],
[2004,2019],
[2000,2019],
[2008,2019],
[2013,2019],
[2005,2019],
[2013,2019],
[2003,2019],
[1955,2005],
[1999,2019],
[2003,2019],
[2004,2016],
[2002,2013],
[1967,2019],
[2005,2010],
[2004,2019],
[1953,2019],
[2011,2019],
[2005,2019],
[1995,2014],
[1958,2019],
[1974,2019],
[1999,2019],
[1999,2019],
[2000,2019],
[2012,2019],
[1964,2019],
[1995,2019],
[2002,2009],
[2009,2019],
[2011,2019],
[2011,2017],
[1958,2019],
[2005,2018],
[2001,2010],
[1996,2010],
[1947,2016],
[1997,2014],
[1970,2019],
[1966,2019],
[1989,2011],
[1962,2016],
[1998,2019],
[1993,2019],
[2009,2019],
[1955,2011],
[1961,2014],
[1994,2009],
[2007,2019],
[2001,2019],
[1997,2019],
[1991,2019],
[1975,2019],
[1953,2019],
[1958,2019],
[2008,2019],
[2011,2019],
[2009,2019],
[2000,2018],
[2006,2019],
[1964,2019],
[1986,2019],
[1991,2019],
[2010,2019],
[1983,1991],
[2007,2019],
[1992,2019],
[1992,2019],
[2010,2019],
[1992,2019],
[2000,2019],
[1984,2019],
[1997,2019],
[1981,2019],
[2007,2019],
[1995,2019],
[2003,2019],
[1996,2019],
[1998,2019],
[2001,2019],
[2014,2018],
[1999,2019],
[2005,2019],
[2012,2019],
[2003,2008],
[2008,2013],
[2014,2019],
[1979,2019],
[2007,2019],
[1993,2019],
[2002,2012],
[2007,2017],
[2015,2019],
[1986,2019],
[2009,2019],
[2010,2019],
[2002,2019],
[2002,2019],
[2003,2019],
[2010,2019],
[1997,2019],
[1987,2019],
[2006,2019],
[2007,2019],
[2006,2015],
[2007,2019],
[2007,2018],
[2007,2019],
[1985,2011],
[2002,2012],
[2002,2012],
[2013,2019],
[2004,2019],
[2003,2018],
[2012,2015],
[2008,2019],
[2006,2017],
[2007,2011],
[2003,2015],
[2007,2017],
[1978,2011],
[2003,2009],
[1994,2019],
[2004,2019],
[1998,2019],
[1990,2019],
[2003,2019],
[1990,2019],
[2008,2019],
[1994,2019],
[2004,2019],
[2007,2019],
[2000,2019],
[2005,2010],
[1962,2008],
[1967,2019],
[2003,2019],
[2000,2019],
[2000,2018],
[2000,2018],
[2005,2016],
[1998,2019],
[1997,2019],
[1991,2019],
[2000,2019],
[1985,2019],
[1995,2019],
[1985,2019],
[1985,2019],
[2007,2014],
[2001,2019],
[2001,2019],
[1996,2019],
[2001,2019],
[1998,2019],
[1995,2019],
[2000,2019],
[2012,2019],
[2009,2017],
[1985,2014],
[1996,2019],
[1991,2019],
[2011,2014],
[1993,2019],
[2009,2019],
[2001,2019],
[2003,2019],]
df_top['year_start']=None
df_top['year_end']=None
df_top[['year_start','year_end']]=a

# %%
import dill
dill.dump(df_top, open('df_top.pkd', 'wb'))
df_top = dill.load(open('df_top.pkd', 'rb'))

# %%
X7=X4
for i in range(len(df_top)):
    make=df_top['make0'][i]
    model=df_top['model0'][i]
    start_year=df_top['year_start'][i]
    end_year=df_top['year_end'][i]
    X7=X7.drop(X7[(X7['make0']==make)&(X7['model0']==model)&(X7['year0']>end_year)].index)
    X7=X7.drop(X7[(X7['make0']==model)&(X7['model0']==model)&(X7['year0']<start_year)].index)

# %%
import dill
dill.dump(X7, open('X7.pkd', 'wb'))
#df = dill.load(open('X7.pkd', 'rb'))

# %%
with open('top2.txt', 'w') as f:
    for item in new_list:
        f.write("%s\n" % item)

# %%
dic_mntnc={}
not_worked=[]
for i in range(len(new_list)):
    car=new_list[i]   
    name=car.split(' ')
    url='http://usedfirst.com/cars/'+name[0]+'/'+name[1]+'/'
    page= requests.get(url)
    a=BeautifulSoup(page.text,'lxml')
    table = a.find(lambda tag: tag.name=='table' and tag.has_attr('id') and tag['id']=="salesData")
    try:
        rows = table.findAll("td")
    except:
        try:
            name=car.split(' ')
            url='http://usedfirst.com/cars/'+name[0]+'/'
            page= requests.get(url)
            a=BeautifulSoup(page.text,'lxml')
            table = a.find(lambda tag: tag.name=='table' and tag.has_attr('id') and tag['id']=="salesData")
        except:
            not_worked.append(car)
            continue

    s=0
    rep_cost=[]
    for j in range(int(len(rows)/10)):
        s=j*10
        rep_cost.append(int(rows[s+3].text.strip('$').replace(',','')))
    dic_mntnc[[grouped2['make0']+','+grouped2['model0']][0][i]]=rep_cost
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4a2dd98ff8f1> in <module>()
#       1 dic_mntnc={}
#       2 not_worked=[]
# ----> 3 for i in range(len(new_list)):
#       4     car=new_list[i]
#       5     name=car.split(' ')
#
# NameError: name 'new_list' is not defined

# %%
import dill
#dill.dump(dic_mntnc, open('dic_mntnc.pkd', 'wb'))
dic_mntnc = dill.load(open('dic_mntnc.pkd', 'rb'))

# %%
df_top2=pd.DataFrame()
df_top2['year0']=None
df_top2['make0']=None
df_top2['model0']=None
df_top2['cost']=None
s=0
for i in range(len(df_top)):
    car=[df_top['make0']+','+df_top['model0']][0][i]
    for j in range(len(dic_mntnc[car])):
        if (2018-j<=df_top['year_end'][i]) and (2018-j>=df_top['year_start'][i]):
            df_top2.loc[s,['year0','make0','model0','cost']]=(2018-j,df_top['make0'][i],df_top['model0'][i],dic_mntnc[car][j])
            s+=1
df_top2['year0']=df_top2['year0'].astype(int)
df_top2.dtypes
#df_top2
# Out:
# year0      int64
# make0     object
# model0    object
# cost      object
# dtype: object

# %%
import dill
#dill.dump(df_top2, open('df_top2.pkd', 'wb'))
df_top2 = dill.load(open('df_top2.pkd', 'rb'))

# %%
df_top3=pd.DataFrame()
df_top3['year0']=None
df_top3['Car']=None
df_top3['cost']=None
s=0
for i in range(len(df_top)):
    car=[df_top['make0']+','+df_top['model0']][0][i]
    for j in range(len(dic_mntnc[car])):
        df_top3.loc[s,['year0','Car','cost']]=(2018-j,car,dic_mntnc[car][j])
        s+=1
df_top3['year0']=df_top3['year0'].astype(int)
df_top3.dtypes
#df_top2
# Out:
# year0     int64
# Car      object
# cost     object
# dtype: object

# %%
X5=pd.merge(X4,df_top2, how='left',on=['year0','make0','model0'],sort=False)
X5=X5[X5['cost']>0]

# %%
X6=pd.merge(X2,df_top3, how='left',on=['year0','Car'],sort=False)
X6=X6[X6['cost']>0]

# %%
X8=pd.merge(X7,df_top2, how='left',on=['year0','make0','model0'],sort=False)
X8=X8[X8['cost']>0]

# %%
import dill
#dill.dump(X7, open('X7.pkd', 'wb'))
X7 = dill.load(open('X7.pkd', 'rb'))

# %%
import dill
#dill.dump(X8, open('X8.pkd', 'wb'))
X8 = dill.load(open('X8.pkd', 'rb'))

# %%
import dill
dill.dump(X5, open('X5.pkd', 'wb'))
X5 = dill.load(open('X5.pkd', 'rb'))

# %%
#dfg = df.groupby(['store', 'product']).agg({'sales': ['sum', 'count'], 'rating': 'mean'})
#df.groupby(['make0', 'model0']).size().unstack(level=1, fill_value=0)
#df.groupby(['make0', 'model0']).agg({'make0':'count'})
grouped = pd.pivot_table(X, values=['year0'], index=['Car'],aggfunc=len).reset_index()
grouped.sort_values(['year0'], ascending=[0]).head()
# Out:
#                           Car  year0
# 65                 Ford F 150  30892
# 35   Chevrolet Silverado 1500  23145
# 150                  RAM 1500  16448
# 66                 Ford F 250  12886
# 86                Honda Civic  12826

# %%
#separate make model
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.pipeline import Pipeline
#from sklearn.feature_extraction import DictVectorizer
#from sklearn.linear_model import Ridge
#from sklearn.preprocessing import Imputer, PolynomialFeatures, StandardScaler, OneHotEncoder, MinMaxScaler
#from sklearn.neighbors import KNeighborsRegressor
#from sklearn.model_selection import GridSearchCV
#from sklearn.preprocessing import Imputer
#from sklearn.linear_model import LogisticRegression
#from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
#from sklearn.model_selection import GridSearchCV
#from sklearn.pipeline import Pipeline
#import numpy as np
ct_transformer = ColumnTransformer(
    [('oh_enc', OneHotEncoder(sparse=False), [0,1,2]),],  # the column numbers I want to apply this to
    remainder='passthrough'  # This leaves the rest of my columns in place
)
car_est=Pipeline([
    ('ct' , ct_transformer ),
    ('scl', StandardScaler()),
    ('gbr', GradientBoostingRegressor(loss ='ls', max_depth=6)),
])

car_est.fit(X5[['year0','make0','model0','odometer']],X5[['Price']])

#ct.fit_transform(X.head())
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Pipeline(memory=None,
#      steps=[('ct', ColumnTransformer(n_jobs=None, remainder='passthrough', sparse_threshold=0.3,
#          transformer_weights=None,
#          transformers=[('oh_enc', OneHotEncoder(categorical_features=None, categories=None,
#        dtype=<class 'numpy.float64'>, handle_unknown='error',
#        n_values=Non...one, subsample=1.0, tol=0.0001,
#              validation_fraction=0.1, verbose=0, warm_start=False))])

# %%
#separate make model
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.pipeline import Pipeline
#from sklearn.feature_extraction import DictVectorizer
#from sklearn.linear_model import Ridge
#from sklearn.preprocessing import Imputer, PolynomialFeatures, StandardScaler, OneHotEncoder, MinMaxScaler
#from sklearn.neighbors import KNeighborsRegressor
#from sklearn.model_selection import GridSearchCV
#from sklearn.preprocessing import Imputer
#from sklearn.linear_model import LogisticRegression
#from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
#from sklearn.model_selection import GridSearchCV
#from sklearn.pipeline import Pipeline
#import numpy as np
ct_transformer = ColumnTransformer(
    [('oh_enc', OneHotEncoder(sparse=False), [0,1,2]),],  # the column numbers I want to apply this to
    remainder='passthrough'  # This leaves the rest of my columns in place
)
car_est=Pipeline([
    ('ct' , ct_transformer ),
    ('scl', StandardScaler()),
    ('gbr', GradientBoostingRegressor(loss ='ls', max_depth=6)),
])

car_est.fit(X5[['year0','make0','model0','odometer']],X5[['Price']])

#ct.fit_transform(X.head())
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-91537b10dc57> in <module>()
#      27 ])
#      28
# ---> 29 car_est.fit(X5[['year0','make0','model0','odometer']],X5[['Price']])
#      30
#      31 #ct.fit_transform(X.head())
#
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     265         Xt, fit_params = self._fit(X, y, **fit_params)
#     266         if self._final_estimator is not None:
# --> 267             self._final_estimator.fit(Xt, y, **fit_params)
#     268         return self
#     269
#
# ...

# %%
#Fast score 0.8822975695841913
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.pipeline import Pipeline
#from sklearn.feature_extraction import DictVectorizer
#from sklearn.linear_model import Ridge
#from sklearn.preprocessing import Imputer, PolynomialFeatures, StandardScaler, OneHotEncoder, MinMaxScaler
#from sklearn.neighbors import KNeighborsRegressor
#from sklearn.model_selection import GridSearchCV
#from sklearn.preprocessing import Imputer
#from sklearn.linear_model import LogisticRegression
#from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
#from sklearn.model_selection import GridSearchCV
#from sklearn.pipeline import Pipeline
#import numpy as np
ct_transformer = ColumnTransformer(n_jobs=-1,
    transformers=[('oh_enc', OneHotEncoder(sparse=True), [1,2]),],  # the column numbers I want to apply this to
    remainder='passthrough',  # This leaves the rest of my columns in place    
)
car_est2=Pipeline([
    ('ct' , ct_transformer ),
    ('gbr', GradientBoostingRegressor(loss ='ls', max_depth=12,verbose=10)),
])
#car_est3.fit (X_train,y_train)
car_est2.fit(X4[['year0','make0','model0','odometer']],X4[['Price']])

#ct.fit_transform(X.head())
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/backend/semaphore_tracker.py:74: UserWarning: semaphore_tracker: process died unexpectedly, relaunching.  Some semaphores might leak.
#   warnings.warn('semaphore_tracker: process died unexpectedly, '
# Exception ignored in: <Finalize object, dead>
# Traceback (most recent call last):
#   File "/opt/conda/envs/data3/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/backend/synchronize.py", line 97, in _cleanup
#     semaphore_tracker.unregister(name)
#   File "/opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/backend/semaphore_tracker.py", line 125, in unregister
#     self.ensure_running()
# ...

# %%
#Fast 'car'
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.pipeline import Pipeline
#from sklearn.feature_extraction import DictVectorizer
#from sklearn.linear_model import Ridge
#from sklearn.preprocessing import Imputer, PolynomialFeatures, StandardScaler, OneHotEncoder, MinMaxScaler
#from sklearn.neighbors import KNeighborsRegressor
#from sklearn.model_selection import GridSearchCV
#from sklearn.preprocessing import Imputer
#from sklearn.linear_model import LogisticRegression
#from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
#from sklearn.model_selection import GridSearchCV
#from sklearn.pipeline import Pipeline
#import numpy as np
ct_transformer = ColumnTransformer(n_jobs=-1,
    transformers=[('oh_enc', OneHotEncoder(sparse=True), [0,1,]),],  # the column numbers I want to apply this to
    remainder='passthrough',  # This leaves the rest of my columns in place    
)
car_est4=Pipeline([
    ('ct' , ct_transformer ),
    ('gbr', GradientBoostingRegressor(loss ='ls', max_depth=10)),
])
#car_est3.fit (X_train,y_train)
car_est2.fit(X2[['year0','Car','odometer']],X2[['Price']])

#ct.fit_transform(X.head())
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Pipeline(memory=None,
#      steps=[('ct', ColumnTransformer(n_jobs=-1, remainder='passthrough', sparse_threshold=0.3,
#          transformer_weights=None,
#          transformers=[('oh_enc', OneHotEncoder(categorical_features=None, categories=None,
#        dtype=<class 'numpy.float64'>, handle_unknown='error',
#        n_values=None,...one, subsample=1.0, tol=0.0001,
#              validation_fraction=0.1, verbose=0, warm_start=False))])

# %%
car_est3.score(X6[['year0','Car','odometer']],X6['Price'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-109-bad28beaa762> in <module>()
# ----> 1 car_est3.score(X5[['year0','Car','odometer']],X5['Price'])
#
# /opt/conda/envs/data3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# /opt/conda/envs/data3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ...

# %%
X7[['year0','odometer']]=X7[['year0','odometer']].astype(float)

# %%
#test for MLP
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn.neural_network import MLPRegressor
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

#X_train, X_test, y_train, y_test = train_test_split(X5[['year0','make0','model0','odometer']],X5[['Price']], test_size=0.95, random_state=42,shuffle=True)

ct_transformer = ColumnTransformer(n_jobs=-1,
    transformers=[('oh_enc', OneHotEncoder(sparse=True), [1,2]),('scl', StandardScaler(),[0,3])],  # the column numbers I want to apply this to
    remainder='passthrough'  # This leaves the rest of my columns in place
)

car_est3=Pipeline([
    ('ct' , ct_transformer ),
    ('clf', MLPRegressor(solver='adam', 
                         alpha=.0001,hidden_layer_sizes=(50,50,50),
                         random_state=1,max_iter=200,verbose=10,learning_rate_init=.1, learning_rate='adaptive')),
])
#y_float = np.asarray(y_train, dtype="|S6")
#car_est3.fit (X_train,y_train)
car_est3.fit(X7[['year0','make0','model0','odometer']],X7[['Price']])
#predicted = car_est.predict(X_test)
#residual = y_test['Price'] - predicted
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:1316: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 1, loss = 7637181.25319229
# Iteration 2, loss = 6428517.05836056
# Iteration 3, loss = 6363241.02620364
# Iteration 4, loss = 6310090.49363261
# Iteration 5, loss = 6241469.45039964
# Iteration 6, loss = 6179430.78601496
# Iteration 7, loss = 6155464.49962075
# Iteration 8, loss = 6140644.51067448
# Iteration 9, loss = 6115449.56399713
# Iteration 10, loss = 6122103.77004148
# Iteration 11, loss = 6114710.69846015
# Iteration 12, loss = 6100791.77311690
# Iteration 13, loss = 6108244.94340881
# Iteration 14, loss = 6098408.28461046
# Iteration 15, loss = 6096442.52633959
# Iteration 16, loss = 6087010.54690724
# Iteration 17, loss = 6067057.59579311
# ...

# %%
#test for MLP
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn.neural_network import MLPRegressor
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

#X_train, X_test, y_train, y_test = train_test_split(X5[['year0','make0','model0','odometer']],X5[['Price']], test_size=0.95, random_state=42,shuffle=True)

ct_transformer = ColumnTransformer(#n_jobs=-1,
    transformers=[('oh_enc', OneHotEncoder(sparse=True), [1,2]),('scl', StandardScaler(),[0,3])],  # the column numbers I want to apply this to
    remainder='passthrough'  # This leaves the rest of my columns in place
)

car_est3=Pipeline([
    ('ct' , ct_transformer ),
    ('clf', MLPRegressor(solver='adam', 
                         alpha=.0001,hidden_layer_sizes=(10,10,10),
                         random_state=1,max_iter=200,verbose=10,learning_rate_init=.1, learning_rate='adaptive')),
])
#y_float = np.asarray(y_train, dtype="|S6")
#car_est3.fit (X_train,y_train)
car_est3.fit(X7[['year0','make0','model0','odometer']].values,X7[['Price']].T.values[0])
#predicted = car_est.predict(X_test)
#residual = y_test['Price'] - predicted
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# Iteration 1, loss = 7637181.25319229
# Iteration 2, loss = 6428517.05836056
# Iteration 3, loss = 6363241.02620364
# Iteration 4, loss = 6310090.49363261
# Iteration 5, loss = 6241469.45039964
# Iteration 6, loss = 6179430.78601496
# Iteration 7, loss = 6155464.49962075
# Iteration 8, loss = 6140644.51067448
# Iteration 9, loss = 6115449.56399713
# Iteration 10, loss = 6122103.77004148
# Iteration 11, loss = 6114710.69846015
# Iteration 12, loss = 6100791.77311690
# Iteration 13, loss = 6108244.94340881
# ...

# %%
X7[['Price']].T.values[0]
# Out:
# array([24700.,  1710., 15200., ..., 14250.,  2470.,  4750.])

# %%
car_est3.predict([[float(2018),'Toyota','Corolla',float(20000)]])
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([14302.91105915])

# %%
car_est3.score(X7[['year0','make0','model0','odometer']],X7['Price'])
# Out:
# 0.8737211266218141

# %%
import pickle
pickle.dump(car_est2, open('car_est2.sav', 'wb'))

#car_est = pickle.load(open('car_est2.sav', 'rb'))

# %%
import pickle
pickle.dump(car_est3, open('car_est6.sav', 'wb'))

#car_est3 = pickle.load(open('car_est3.sav', 'rb'))

# %%
#viz
cond1=(X7['make0']=='BMW')&(X7['model0']=='335 i')&(X7['year0']==2015)
y_real=X7['Price'][cond1]
X_plot1=X7[['year0','make0','model0','odometer']][cond1]
y_predicted=car_est3.predict(X_plot1)
# here we set the figure size to 15x8
plt.figure(figsize=(15, 8))
# plot two values price per year_model
plt.scatter(X_plot1.odometer, y_real, label="real")
plt.scatter(X_plot1.odometer, y_predicted, label="predicted")
#plt.plot(X[(X['status']=='clean')&(X['Car']=='Toyota Corolla')&(X['year0']==2014)].Miles,y_predicted, label="Predicted")
plt.xlabel("mileage", fontsize=17)
plt.ylabel("price (USD)", fontsize=17)
plt.title("Mileage observation - real price vs predicted (2014 Toyota Corolla)",fontsize=18)
plt.legend()
plt.show()

# %%
#'Car'
cond1=(X6['Car']=='BMW,335 i')&(X6['year0']==2014)
y_real=X6['Price'][cond1]
X_plot1=X6[['year0','Car','odometer']][cond1]
y_predicted=car_est3.predict(X_plot1)
# here we set the figure size to 15x8
plt.figure(figsize=(15, 8))
# plot two values price per year_model
plt.scatter(X_plot1.odometer, y_real, label="real")
plt.scatter(X_plot1.odometer, y_predicted, label="predicted")
#plt.plot(X[(X['status']=='clean')&(X['Car']=='Toyota Corolla')&(X['year0']==2014)].Miles,y_predicted, label="Predicted")
plt.xlabel("mileage", fontsize=17)
plt.ylabel("price (USD)", fontsize=17)
plt.title("Mileage observation - real price vs predicted (2014 Toyota Corolla)",fontsize=18)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-f473926c25f5> in <module>()
#       1 #'Car'
# ----> 2 cond1=(X6['Car']=='BMW,335 i')&(X6['year0']==2014)
#       3 y_real=X6['Price'][cond1]
#       4 X_plot1=X6[['year0','Car','odometer']][cond1]
#       5 y_predicted=car_est3.predict(X_plot1)
#
# NameError: name 'X6' is not defined

# %%
cond2=(X7['make0']=='Toyota')&(X7['model0']=='Corolla')&(X7['odometer']>=40000) &(X7['odometer']<=60000)
X_plot2=X7[['year0','make0','model0','odometer']][cond2]
y_real=X7['Price'][cond2]
y_predicted=car_est3.predict(X_plot2)
#viz
# here we set the figure size to 15x8
plt.figure(figsize=(15, 8))

#plt.rcParams['figure.figsize'] = 16,5
# plot two values price per year_model
plt.scatter(X_plot2.year0, y_real, label="real")
plt.scatter(X_plot2.year0, y_predicted, label="predicted")
#plt.plot(X[(X['status']=='clean')&(X['Car']=='Toyota Corolla')&(X['year0']==2014)].Miles,y_predicted, label="Predicted")
plt.xlabel("year built", fontsize=17)
plt.ylabel("price (USD)", fontsize=17)
plt.title("model year observations - real price vs predicted (Toyota Corolla)",fontsize=18)
plt.legend()
plt.show()

# %%
#'Car'
cond2=(X6['Car']=='BMW,335 i')&(X6['odometer']>=40000) &(X6['odometer']<=60000)
X_plot2=X6[['year0','Car','odometer']][cond2]
y_real=X6['Price'][cond2]
y_predicted=car_est2.predict(X_plot2)
#viz
# here we set the figure size to 15x8
plt.figure(figsize=(15, 8))

#plt.rcParams['figure.figsize'] = 16,5
# plot two values price per year_model
plt.scatter(X_plot2.year0, y_real, label="real")
plt.scatter(X_plot2.year0, y_predicted, label="predicted")
#plt.plot(X[(X['status']=='clean')&(X['Car']=='Toyota Corolla')&(X['year0']==2014)].Miles,y_predicted, label="Predicted")
plt.xlabel("year built", fontsize=17)
plt.ylabel("price (USD)", fontsize=17)
plt.title("model year observations - real price vs predicted (Toyota Corolla)",fontsize=18)
plt.legend()
plt.show()

# %%
cond2=(X5['make0']=='BMW')&(X5['model0']=='325 i')&(X5['odometer']>=40000) &(X5['odometer']<=60000)
X_plot2=X5[['year0','make0','model0','odometer']][cond2]

# %%
cond2=(X5['make0']=='Ford')&(X5['model0']=='Mustang')&(X5['odometer']>=40000) &(X5['odometer']<=60000)
X5[['year0','make0','model0','odometer']][cond2]
# Out:
#         year0 make0   model0  odometer
# 431      2007  Ford  Mustang     60000
# 1053     2013  Ford  Mustang     55000
# 1128     2015  Ford  Mustang     44000
# 2049     2006  Ford  Mustang     43938
# 2349     2007  Ford  Mustang     57200
# 2636     2012  Ford  Mustang     44000
# 2747     2015  Ford  Mustang     48595
# 2760     2010  Ford  Mustang     40000
# 3324     2007  Ford  Mustang     51000
# 3752     2015  Ford  Mustang     55000
# 4571     2006  Ford  Mustang     40000
# 5271     2014  Ford  Mustang     52000
# 6753     2015  Ford  Mustang     48000
# 7242     2011  Ford  Mustang     49000
# 7487     2012  Ford  Mustang     49500
# 7821     2008  Ford  Mustang     54000
# 8130     2006  Ford  Mustang     60000
# 8136     2015  Ford  Mustang     60000
# 8680     2007  Ford  Mustang     48300
# 10097    2012  Ford  Mustang     43000
# 11243    2015  Ford  Mustang     41000
# 12649    2015  Ford  Mustang     43100
# 12827    2016  Ford  Mustang     40000
# ...

# %%
years_to_keep=5
budget=10000
def cost_calc(year,make,model,span):
    cond=(df_top2['make0']==make)&(df_top2['model0']==model)
    current_price=car_est2.predict([[year,make,model,(2019-year)*15000]])
    future_price=car_est2.predict([[year-span,make,model,(2019-year+span)*15000]])
    price_drop=current_price[0]-future_price[0]
    maintnc_cost=0
    for i in range(span):
        maintnc_cost=list(df_top2['cost'][cond&(df_top2['year0']==year-i)])[0]+maintnc_cost
    return price_drop+maintnc_cost
possible_cars=pd.DataFrame(columns=['year0','make0','model0','total_cost'])
s=0
for i in range(len(df_top)):
    make,model=df_top.loc[i,['make0','model0']]
    for j in range(len(df_top2[['cost']][(df_top2['make0']==make)&(df_top2['model0']==model)])-years_to_keep):
        year=2018-j
        est_price=car_est2.predict([[year,make,model,(2019-year)*15000]])
        if (est_price>budget-500)&(est_price<budget+500):
            possible_cars.loc[s] = [year,make,model,cost_calc(year,make,model,years_to_keep)]
            s+=1

# %%
#mlp
years_to_keep=3
budget=15000
annual_mileage=12000
tol=500
def cost_calc3(year,make,model,span):
    cond=(df_top2['make0']==make)&(df_top2['model0']==model)
    current_price=car_est3.predict([[year,make,model,(2019-year)*15000]])
    future_price=car_est3.predict([[year-span,make,model,(2019-year)*15000+span*annual_mileage]])
    price_drop=current_price[0]-future_price[0]
    maintnc_cost=0
    for i in range(span):
        maintnc_cost=list(df_top2['cost'][cond&(df_top2['year0']==year-i)])[0]+maintnc_cost
    return price_drop+maintnc_cost
possible_cars3=pd.DataFrame(columns=['year0','make0','model0','total_cost'])
s=0
for i in range(len(df_top)):
    make,model=df_top.loc[i,['make0','model0']]
    for j in range(len(df_top2[['cost']][(df_top2['make0']==make)&(df_top2['model0']==model)])-years_to_keep):        
        year=max(df_top2[['year0']][(df_top2['make0']==make)&(df_top2['model0']==model)].values)[0]-j
#        if (year-min(df_top2[['year0']][(df_top2['make0']==make)&(df_top2['model0']==model)].values)[0])+1<=years_to_keep: continue
        est_price=car_est3.predict([[year,make,model,(2019-year)*15000]])
        if (est_price>budget-tol)&(est_price<budget+tol):
            possible_cars3.loc[s] = [year,make,model,cost_calc3(year,make,model,years_to_keep)]
            s+=1

# %%
possible_cars3
# Out:
#    year0          make0          model0    total_cost
# 0   2012          Acura             MDX   9522.644065
# 1   2013           Audi             A 6  11523.052474
# 2   2014            BMW           328 i  12239.325001
# 3   2013            BMW             X 5  11928.882417
# 4   2016          Buick          Encore   5573.285721
# 5   2013       Cadillac             SRX  11054.506592
# 6   2015      Chevrolet          Camaro   5678.510440
# 7   2013      Chevrolet        Colorado   9961.345239
# 8   2018      Chevrolet           Cruze   5797.455415
# 9   2016      Chevrolet          Impala   8349.967268
# 10  2017      Chevrolet          Malibu   6208.675725
# 11  2016      Chevrolet            Volt   7564.098577
# 12  2017       Chrysler             200   8159.404685
# 13  2015       Chrysler    Town Country   8450.238048
# 14  2013          Dodge      Challenger   7873.110117
# 15  2014          Dodge         Charger   9204.143867
# ...

# %%
#'car'
years_to_keep=5
budget=10000
def cost_calc2(year,car,span):
    cond2=(df_top3['Car']==car)
    current_price=car_est2.predict([[year,car,(2019-year)*15000]])
    future_price=car_est2.predict([[year-span,car,(2019-year+span)*15000]])
    price_drop=current_price[0]-future_price[0]
    maintnc_cost=0
    for i in range(span):
        maintnc_cost=list(df_top3['cost'][cond2&(df_top2['year0']==year-i)])[0]+maintnc_cost
    return price_drop+maintnc_cost
possible_cars2=pd.DataFrame(columns=['year0','Car','total_cost'])
s=0
for i in range(len(df_top)):
    car=df_top.loc[i,['Car']][0]
    for j in range(len(df_top3[['cost']][(df_top3['Car']==car)])-years_to_keep):
        year=2018-j
        est_price=car_est2.predict([[year,car,(2019-year)*15000]])
        if (est_price>budget-500)&(est_price<budget+500):
            possible_cars2.loc[s] = [year,car,cost_calc2(year,car,years_to_keep)]
            s+=1

# %%
(year,make,model,span)=(2011,'BMW','335 i',5)
cond=(df_top2['make0']==make)&(df_top2['model0']==model)
current_price=car_est2.predict([[year,make,model,(2019-year)*15000]])
future_price=car_est2.predict([[year-span,make,model,(2019-year+span)*15000]])
price_drop=current_price[0]-future_price[0]
maintnc_cost=0
for i in range(span):
    maintnc_cost=list(df_top2['cost'][cond&(df_top2['year0']==year-i)])[0]+maintnc_cost
price_drop
# Out:
# 4228.774588864261

# %%
car_est2.predict([[year,'BMW,535 i',(2019-year)*15000]])
# Out:
# array([10390.63637849])

# %%
year=2018
make='Acura'
model='MDX'
span=3
#cond=(df_top2['make0']=='Acura')&(df_top2['model0']=='MDX')&(df_top2['year0']==2018)
cond=(df_top2['make0']==make)&(df_top2['model0']==model)
current_price=car_est2.predict([[year,make,model,(2019-year)*15000]])
future_price=car_est2.predict([[year-span,make,model,(2019-year-span)*15000]])
price_drop=current_price-future_price
maintnc_cost=0
for i in range(span):
    maintnc_cost=list(df_top2['cost'][cond&(df_top2['year0']==year-i)])[0]+maintnc_cost
maintnc_cost
# Out:
# 1197

# %%
cond2=(X5['make0']=='BMW')&(X5['model0']=='325 i')
X5[['year0','make0','model0','odometer']][cond2]
# Out:
#         year0 make0 model0  odometer
# 370      2006   BMW  325 i    120000
# 890      2006   BMW  325 i    108765
# 2867     2006   BMW  325 i    108298
# 3174     2006   BMW  325 i    118219
# 5322     2006   BMW  325 i    168500
# 6866     2006   BMW  325 i     48000
# 8987     2006   BMW  325 i    136000
# 9109     2006   BMW  325 i    175000
# 9589     2006   BMW  325 i    118295
# 11424    2006   BMW  325 i    133200
# 13512    2006   BMW  325 i     16500
# 14441    2010   BMW  325 i    160350
# 14824    2006   BMW  325 i    155155
# 15201    2006   BMW  325 i    128000
# 15736    2006   BMW  325 i    114230
# 18047    2006   BMW  325 i    150000
# 19814    2006   BMW  325 i    161000
# 20378    2006   BMW  325 i    127000
# 21195    2006   BMW  325 i    169000
# 23675    2006   BMW  325 i    124458
# 23855    2006   BMW  325 i    150000
# 27462    2006   BMW  325 i    130466
# 27591    2006   BMW  325 i    179000
# 27887    2006   BMW  325 i     83587
# ...

# %%
#cross validation
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn import metrics

X_train, X_test, y_train, y_test = train_test_split(X5[['year0','make0','model0','odometer']],X5[['Price']], test_size=0.2, random_state=42,shuffle=True)


#car_est2.fit (X_train, y_train)
predicted = car_est2.predict(X_test)
residual = y_test['Price'] - predicted

fig = plt.figure(figsize=(30,30))
ax1 = plt.subplot(211)
sns.distplot(residual, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.title('Residual counts',fontsize=35)
plt.xlabel('Residual',fontsize=25)
plt.ylabel('Count',fontsize=25)

ax2 = plt.subplot(212)
plt.scatter(predicted, residual, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Predicted',fontsize=25)
plt.ylabel('Residual',fontsize=25)
plt.axhline(y=0)
plt.title('Residual vs. Predicted',fontsize=35)

plt.show()

# %%
fig = plt.figure(figsize=(30,30))
ax2 = plt.subplot(212)
plt.scatter(predicted, np.asanyarray(residual)/predicted, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Predicted',fontsize=25)
plt.ylabel('Residual/Predicted',fontsize=25)
plt.axhline(y=0)
plt.title('Residual vs. Predicted',fontsize=35)

plt.show()

# %%
rmse = np.sqrt(mean_squared_error(y_test, predicted))
scores = cross_val_score(car_est, X5[['year0','make0','model0','odometer']],X5['Price'], cv=12)

print('\nCross Validation Scores:')
print(scores)
print('\nMean Score:')
print(scores.mean())
print('\nRMSE:')
print(rmse)

#car_est.fit(X_train, y_train)
#pred=car_est.predict(X_test)
#score = -cross_val_score(car_est, X_test, y_test,cv=10, scoring='neg_mean_squared_error').mean()
#print(score)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-0302ae199c77> in <module>()
#       1 rmse = np.sqrt(mean_squared_error(y_test, predicted))
# ----> 2 scores = cross_val_score(car_est, X5[['year0','make0','model0','odometer']],X5['Price'], cv=12)
#       3
#       4 print('\nCross Validation Scores:')
#       5 print(scores)
#
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     400                                 fit_params=fit_params,
#     401                                 pre_dispatch=pre_dispatch,
# --> 402                                 error_score=error_score)
#     403     return cv_results['test_score']
#     404
#
# ...

# %%
from sklearn.metrics import mean_squared_error
residual = y_test['Price'] - predicted

fig = plt.figure(figsize=(30,30))
ax1 = plt.subplot(211)
sns.distplot(residual, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.title('Residual counts',fontsize=35)
plt.xlabel('Residual',fontsize=25)
plt.ylabel('Count',fontsize=25)

ax2 = plt.subplot(212)
plt.scatter(predicted, residual, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Predicted',fontsize=25)
plt.ylabel('Residual',fontsize=25)
plt.axhline(y=0)
plt.title('Residual vs. Predicted',fontsize=35)

plt.show()

rmse = np.sqrt(mean_squared_error(y_test, predicted))
scores = cross_val_score(car_est, X4[['year0','make0','model0','odometer']],X4['Price'], cv=12)

print('\nCross Validation Scores:')
print(scores)
print('\nMean Score:')
print(scores.mean())
print('\nRMSE:')
print(rmse)

#car_est.fit(X_train, y_train)
#pred=car_est.predict(X_test)
#score = -cross_val_score(car_est, X_test, y_test,cv=10, scoring='neg_mean_squared_error').mean()
#print(score)
# Out:
# Cross Validation Scores:
# [0.81984112 0.80512939 0.79576347 0.80716518 0.80335399 0.81817161
#  0.78322116 0.79951559 0.82980745 0.79907459 0.8201084  0.80059822]
#
# Mean Score:
# 0.8068125126675119
#
# RMSE:
# 3974.902501873213

# %%
score = -cross_val_score(car_est, X_test, y_test,cv=10, scoring='neg_mean_squared_error').mean()
print(score)
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
#from sklearn.feature_extraction import DictVectorizer
#from sklearn.linear_model import Ridge
#from sklearn.preprocessing import Imputer, PolynomialFeatures, StandardScaler, OneHotEncoder, MinMaxScaler
#from sklearn.neighbors import KNeighborsRegressor
#from sklearn.model_selection import GridSearchCV
#from sklearn.preprocessing import Imputer
#from sklearn.linear_model import LogisticRegression
#from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(X[['year0','Car','Miles']],y, test_size=0.2, random_state=42,shuffle=True)
ct_transformer = ColumnTransformer(
    [('oh_enc', OneHotEncoder(sparse=False), [1]),],  # the column numbers I want to apply this to
    remainder='passthrough'  # This leaves the rest of my columns in place
)
car_est=Pipeline([
    ('ct' , ct_transformer ),
    ('scl', StandardScaler()),
    ('gbr', GradientBoostingRegressor(loss ='ls', max_depth=6)),
])
car_est.fit (X_train, y_train)
predicted = car_est.predict(X_test)
residual = y_test - predicted

fig = plt.figure(figsize=(30,30))
ax1 = plt.subplot(211)
sns.distplot(residual, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.title('Residual counts',fontsize=35)
plt.xlabel('Residual',fontsize=25)
plt.ylabel('Count',fontsize=25)

ax2 = plt.subplot(212)
plt.scatter(predicted, residual, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Predicted',fontsize=25)
plt.ylabel('Residual',fontsize=25)
plt.axhline(y=0)
plt.title('Residual vs. Predicted',fontsize=35)

plt.show()

rmse = np.sqrt(mean_squared_error(y_test, predicted))
scores = cross_val_score(car_est, [['year0','Car','Miles']], y, cv=12)

print('\nCross Validation Scores:')
print(scores)
print('\nMean Score:')
print(scores.mean())
print('\nRMSE:')
print(rmse)
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-12f1621b9967> in <module>()
#      30 car_est.fit (X_train, y_train)
#      31 predicted = car_est.predict(X_test)
# ---> 32 residual = y_test - predicted
#      33
#      34 fig = plt.figure(figsize=(30,30))
#
# /opt/conda/envs/data3/lib/python3.6/site-packages/pandas/core/ops.py in f(self, other, axis, level, fill_value)
#    1545     def f(self, other, axis=default_axis, level=None, fill_value=None):
#    1546
# -> 1547         other = _align_method_FRAME(self, other, axis)
#    1548
# ...

# %%
np.asanyarray(y_test) - predicted

# %%
print('Variance score: %.2f' % r2_score(y_test, predicted))

# %%
from sklearn.metrics import r2_score
r2_score(y.head(), car_est.predict(X.head()))
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 0.9253051556480631

# %%
X
# Out:
# array([[0., 1., 2., 2.],
#        [1., 1., 0., 1.]])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import Normalizer
import numpy as np
ct = ColumnTransformer([("norm1", Normalizer(norm='l1'), [0, 1]),
                        ("norm2", Normalizer(norm='l1'), slice(2, 4))])
X = np.array([[0., 1., 2., 2.],
              [1., 1., 0., 1.]])
# Normalizer scales each row of X to unit norm. A separate scaling
# is applied for the two first and two last elements of each

# row independently.
ct.fit_transform(X)
# Out:
# array([[0. , 1. , 0.5, 0.5],
#        [0.5, 0.5, 0. , 1. ]])

# %%
np.asanyarray(y)
# Out:
# array([[42500],
#        [16250],
#        [15000],
#        ...,
#        [ 6994],
#        [ 3400],
#        [ 6991]])
