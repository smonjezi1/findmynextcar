# %%
# %load_ext sql
# %sql sqlite:///carigslist_data_main.db
# Out:
# 'Connected: @carigslist_data_main.db'

# %%
# %%sql
# SELECT * FROM sqlite_master WHERE "type"='table';
# Out:
#  * sqlite:///carigslist_data_main.db
# Done.
# [('table', 'data', 'data', 63907, 'CREATE TABLE data(\n  City,\n  Miles,\n  ID,\n  Name,\n  Price,\n  date,\n  url,\n  VIN,\n  odometer,\n  status,\n  model\n)')]

# %%
# %%sql
# SELECT * FROM data
# GROUP BY model
# ORDER BY ID DESC
# LIMIT 50
# Out:
#  * sqlite:///carigslist_data_main.db
# Done.
# [('youngstown', 155000, '6812700730', '2006 Jeep Liberty', '$5000', '2019-02-06 01:32', 'https://youngstown.craigslist.org/cto/d/youngstown-2006-jeep-liberty/6812700730.html', None, '155000', 'clean', '2006 jeep liberty'),
#  ('yuma', 160000, '6812698911', '2007 Chrysler Sebring 2.7', '$2600', '2019-02-05 22:23', 'https://yuma.craigslist.org/cto/d/somerton-2007-chrysler-sebring-27/6812698911.html', None, '160000', 'clean', '2007 chrysler sebring 4-door'),
#  ('yakima', 65000, '6812688086', '2016 Chevrolet cruze', '$8500', '2019-02-05 21:35', 'https://yakima.craigslist.org/cto/d/yakima-2016-chevrolet-cruze/6812688086.html', None, '65000', 'rebuilt', '2016 chevrolet'),
#  ('yuma', 107000, '6812687349', 'Jeep wrangler lj', '$15000', '2019-02-05 21:40', 'https://yuma.craigslist.org/cto/d/yuma-jeep-wrangler-lj/6812687349.html', None, '107000', 'clean', '2006 2006 jeep wrangler lj'),
# ...

# %%
import sqlite3
import pandas as pd
# Create your connection.
cnx = sqlite3.connect('carigslist_data_main.db')

df = pd.read_sql_query("SELECT * FROM data", cnx)
cnx.close()

# %%
import urllib.request, json 
with urllib.request.urlopen("https://vpic.nhtsa.dot.gov/api/vehicles/GetMakesForVehicleType/car?format=json") as url:
    data = json.loads(url.read().decode())

# %%
car_makes=[]
for i in data['Results']:
    car_makes.append((i['MakeId'],i['MakeName']))
#car_makes

# %%
import requests
import json
d_make_models={}
for make in car_makes:
    response = json.loads(requests.get("https://vpic.nhtsa.dot.gov/api/vehicles/GetModelsForMakeId/"+ str(make[0]) + "?format=json").text)
    make_models=[]
    for i in response['Results']:
        make_models.append(i['Model_Name'])
    d_make_models[i['Make_Name']]=make_models

# %%
import dill
#sorted(list(d_make_models.keys()))
#dill.dump(d_make_models, open('d_make_models.pkd', 'wb'))
d_make_models = dill.load(open('d_make_models.pkd', 'rb'))

# %%
 car_makes_trimed=['AM General',
 'Acura',
 'Alfa Romeo',
 'Aston Martin',
 'Audi',
 'Avanti Motors',
 'BMW',
 'Bentley',
 'Bugatti',
 'Buick',
 'Cadillac',
 'Chevrolet',
 'Chrysler',
 'Dodge',
 'Ferrari',
 'Fiat',
 'Ford',
 'GMC',
 'Genesis',
 'Honda',
 'Hyundai',
 'Infiniti',
 'Isuzu',
 'Jaguar',
 'Kia',
 'Lamborghini',
 'Lexus',
 'Lincoln',
 'Lotus',
 'MINI',
 'Maserati',
 'Maybach',
 'Mazda',
 'Mclaren',
 'Mercedes-Benz',
 'Mercury',
 'Mitsubishi',
 'Nina',
 'Nissan',
 'Oldsmobile',
 'Pontiac',
 'Porsche',
 'Rolls Royce',
 'SAAB',
 'Saturn',
 'Subaru',
 'Suzuki',
 'Tesla',
 'Toyota',
 'Volkswagen',
 'Volvo']
d_make_models_trimed={}
for i in car_makes_trimed:
    d_make_models_trimed[i]=d_make_models[i]

# %%
chev_list=[
'Astro',
'Avalanche',
'Aveo',
'Bel Air',
'Beretta',
'Blazer',
'Bolt EV',
'Camaro',
'Caprice',
'Captiva Sport',
'Cavalier',
'Chevelle',
'Chevette',
'City Express',
'Classic',
'Cobalt',
'Colorado',
'Confederate',
'Corsica',
'Corvair',
'Corvette',
'Corvette Stingray',
'Cruze',
'El Camino',
'Equinox',
'Express 1500',
'Fleetline',
'Fleetmaster',
'HHR',
'Impala',
'Independence',
'Laguna',
'Lumina',
'Malibu',
'Master',
'Metro',
'Monte Carlo',
'Nova',
'Prizm',
'S-10',
'S-10 Blazer',
'SS',
'SSR',
'Silverado',
'Sonic',
'Spark',
'Spark EV',
'Suburban',
'Superior',
'Tahoe',
'Tracker',
'TrailBlazer',
'Traverse',
'Trax',
'Uplander',
'V30',
'Vega',
'Venture',
'Volt']
d_make_models_trimed['Chevrolet']=chev_list

# %%
del d_make_models_trimed['Toyota']

# %%
Scion_list=['FR-S',
'iA',
'iM',
'iQ',
'tC',
'xA',
'xB',
'xD']
d_make_models_trimed['Scion']=Scion_list

# %%
d_make_models_trimed['Toyota']= ['Corolla',
  'PRIUS',
  'LAND CRUISER',
  'Highlander',
  '4-Runner',
  'RAV4',
  'Tacoma',
  'FJ Cruiser',
  'Yaris',
  'Avalon',
  'Matrix',
  'Tundra',
  'Sienna',
  'Camry',
  'Solara',
  'Sequoia',
  'Venza',
  'FCHV-adv',
  'Tercel',
  'Celica',
  'Celica Supra',
  'Supra',
  'MR2',
  'Paseo',
  'Echo',
  'Cressida',
  '1/2 ton',
  '1-ton',
  'Cargo Van',
  'Previa',
  'T100',
  'Mirai',
  'Compact Truck',
  '86',
  'Prius V',
  'Prius C',
  'Prius Plug-in',
  'Pick-Up',
  'Van',
  'Starlet',
  'Corona',
  'COROLLA iM',
  'C-HR',
  'CAMRY HYBRID',
  'Prius Prime',
  'Yaris iA']

# %%
d_make_models_trimed['Land Rover']=['Defender',
'Discovery Sport',
'Discovery',
'Freelander',
'LR2',
'LR3',
'LR4',
'Range Rover Evoque',
'Range Rover Sport',
'Range Rover Velar',
'Range Rover',
'Series II',
'Series III']

# %%
Mercedes_list=['AMG C',
'AMG CLA',
'AMG E',
'AMG GL',
'AMG GLA',
'AMG GLC',
'AMG GLE',
'AMG GLS',
'AMG GT',
'AMG S',
'AMG SL',
'AMG SLC',
'CLA',
'CLK',
'CLS',
'SLC',
'SLK',
'SLR',
'SLS',
'CLS',
'GLA',
'GLC',
'GLE',
'GLK',
'GLS',
'Maybach',
'SL',
'CL',               
'C 250',
'C 300',
'C 350',
'C 350e',
'C 400',
'C 450',
'C 63',
'C 220',
'C 230',
'C 240',
'C 280',
'C 32',
'C 320',
'C 43',
'C 55',
'S 63',
'S 65',
'S 55',
'S 600',
'E 250',
'E 300',
'E 350',
'E 400',
'E 450',
'E 550',
'E 63',
'E 300',
'E 320',
'E 400',
'E 420',
'E 430',
'E 500',
'E 55',
'G 63',               
'GL 63',
'GL',
'ML 55',
'ML 63',
'ML',
'A',
'C',
'E',
'S',
'G',
'R',             
'B',             
'M',
'Sprinter']
d_make_models_trimed['Mercedes-Benz']=Mercedes_list

# %%
Jeep_list=['CJ',
'Cherokee',
'Comanche',
'Commander',
'Commando',
'Compass',
'Grand Cherokee',
'Grand Wagoneer',
'Liberty',
'New Compass',
'Patriot',
'Renegade',
'Scrambler',
'Wagoneer',
'Wrangler']
d_make_models_trimed['Jeep']=Jeep_list

# %%
d_make_models_trimed['Hummer']=['H1',
'H2',
'H3',
'H3T']

# %%
mini_list=d_make_models_trimed['MINI']
del d_make_models_trimed['MINI']
d_make_models_trimed['MINI']=mini_list

# %%
d_make_models_trimed['Chevrolet']=list(set(d_make_models_trimed['Chevrolet'])-set(['Chevy']))
d_make_models_trimed['VW']=d_make_models_trimed['Volkswagen']
d_make_models_trimed['Chevy']=d_make_models_trimed['Chevrolet']

# %%
d_make_models_trimed['Nissan']=list(set(d_make_models_trimed['Nissan'])-set(['Pickup']))
d_make_models_trimed['Isuzu']=list(set(d_make_models_trimed['Isuzu'])-set(['Pickup']))

# %%
d_make_models_trimed.values()
# Out:
# dict_values([['MV-1'], ['ZDX', 'RDX', 'RL', 'TL', 'TSX', 'MDX', 'RLX', 'ILX', 'RSX', 'Integra', 'CL', 'NSX', 'Legend', 'TLX', 'SLX', 'Vigor'], ['4C', '8C Competizione Spider', '164', 'Giulia (952)', 'Spider ', 'Milano', 'GTV6'], ['V8 Vantage', 'DBS', 'DB9', 'Rapide', 'V12 Vantage', 'Virage', 'Vanquish', 'DB11', 'Lagonda', 'Vantiage', 'V8', 'Vanquish S', 'Vanquish Zagato'], ['TT', 'A4', 'S4', 'A6', 'RS6', 'allroad', 'A8', 'RS4', 'A3', 'S6', 'S8', 'Q7', 'A5', 'S5', 'R8', 'TTS', 'Q5', 'RS5', 'A7', 'TT RS', 'Q3', 'SQ5', '90', '100', 'V8', 'Cabriolet', 'S3', 'S7', 'RS7', 'A4 allroad', 'A3 Sportback e-tron', '5000', '4000', '80', '200', 'Coupe', 'RS 3', 'Q8'], ['Avanti '], ['128i', '135i', '328i', 'M3', '335i', '335is', '335d', 'X6', '528i', '535i', 'X5', '550i', 'X3', '740i', '740Li', '750i', '750Li', '760Li', 'Z4', '750xi', '750Lxi', 'M6', '528xi', '640i', '650i', '650xi', 'G450X', 'F800S', 'F800ST', 'F800GS', 'F800R', 'HP2', 'S1000RR', 'R1200GS', 'R1200R', 'R1200RT', 'K1300S', 'K1300GT'
# ...

# %%
import dill
dill.dump(d_make_models_trimed, open('d_make_models-trimed.pkd', 'wb'))
d_make_models_trimed = dill.load(open('d_make_models-trimed.pkd', 'rb'))

# %%
from fuzzywuzzy import fuzz
import re
def fill_all(string,string2):
    try:
        if string==None: string=''
        if string2==None: string2=''
        string=re.sub(r'4runner','4-Runner',string,flags=re.IGNORECASE)
        string2=re.sub(r'4runner','4-Runner',string2,flags=re.IGNORECASE)
        string=re.sub(r'rav-4|rav 4','RAV4',string,flags=re.IGNORECASE)
        string2=re.sub(r'rav-4|rav 4','RAV4',string2,flags=re.IGNORECASE)
        string=re.sub(r'toyota scion','Scion',string,flags=re.IGNORECASE)
        string2=re.sub(r'toyota scion','Scion',string2,flags=re.IGNORECASE)
        string=string.title()
        string2=string2.title()
        regex1=re.compile(r'\bmercedes.*?benz\b|mercedes[^benz]|mercedes$',flags=re.IGNORECASE)
        if re.search(regex1, string) or re.search(regex1, string2):
            regex2=re.compile(r'\b([a-zA-Z]{1,3})(\d{2,3})\b',flags=re.IGNORECASE)
            string=regex2.sub(r'\1 \2',string)
            string2=regex2.sub(r'\1 \2',string2)
            string=re.sub(regex1, ' Mercedes-Benz ',string)
            string2=re.sub(regex1, ' Mercedes-Benz ',string2)

        regex3=re.compile(r'\bFord\b',flags=re.IGNORECASE)
        if re.search(regex3, string) or re.search(regex3, string2):
            regex4=re.compile(r'\b([a-zA-Z]{1})(\d{3})\b',flags=re.IGNORECASE)
            string=regex4.sub(r'\1-\2',string)
            string2=regex4.sub(r'\1-\2',string2)
        
        regex=re.compile(r'Mazda',flags=re.IGNORECASE)    
        if re.search(regex, string) or re.search(regex, string2):
            regex2=re.compile(r'(mazda).*?(\d{1})',flags=re.IGNORECASE)
            string=regex2.sub(r'mazda \1\2',string)
            string2=regex2.sub(r'mazda \1\2',string2)
            
        string=re.sub(' +', ' ',string)        
        string=string.strip(' ')
        string2=re.sub(' +', ' ',string2)
        string2=string2.strip(' ')
        year_return=None        
        make_return=None
        model_return=None
        yr=0
        for word in re.split('\s|,|\-',string):
            try:
                if (int(word) <=2019) & (int(word) >= 1900):
                    yr=1
                    year_return=int(word)
                    break
            except:
                continue
        if yr==0:
            for word in re.split('\s|,|\-',string2):
                try:
                    if (int(word) <=2019) & (int(word) >= 1900):
                        year_return=int(word)
                        yr=1
                        break
                except:
                    continue
        mk=0
        mdl=0
        makes=list(d_make_models_trimed.keys())
        n_makes=len(makes)
        for i in range(n_makes):
            make=makes[i]
            if fuzz.token_set_ratio(make,string)>90:
                if make=='VW': make = 'Volkswagen'
                if make=='Chevy': make = 'Chevrolet'
                if make=='Lexus':
                    regex2=re.compile(r'\b([a-zA-Z]{2})(\d{3})\b',flags=re.IGNORECASE)
                    string=regex2.sub(r'\1 \2',string)
                    string2=regex2.sub(r'\1 \2',string2)
                make_return=make
                mk=1
                models=d_make_models_trimed[make]
                n_models=len(d_make_models_trimed[make])
                for j in range(n_models):
                    if fuzz.token_set_ratio(models[j],string)>90:
                        model_return=models[j]
                        mdl=1
                        break
                if mdl==0:
                    for j in range(n_models):
                        if fuzz.token_set_ratio(models[j],string2)>90:
                            model_return=models[j]
                            mdl=1
                            break
                break
            if mk==0:
                if fuzz.token_set_ratio(make,string2)>90:
                    if make=='VW': make = 'Volkswagen'
                    if make=='Chevy': make = 'Chevrolet'
                    if make=='Lexus':
                        regex2=re.compile(r'\b([a-zA-Z]{2})(\d{3})\b',flags=re.IGNORECASE)
                        string=regex2.sub(r'\1 \2',string)
                        string2=regex2.sub(r'\1 \2',string2)
                    make_return=make
                    mk=1
                    models=d_make_models_trimed[make]
                    n_models=len(d_make_models_trimed[make])
                    for j in range(n_models):
                        if fuzz.token_set_ratio(models[j],string2)>90:
                            model_return=models[j]
                            mdl=1
                            break
                        if mdl==0:
                            for j in range(n_models):
                                if fuzz.token_set_ratio(models[j],string)>90:
                                    model_return=models[j]
                                    mdl=1
                                    break
                    break
                    
        if mk==0:
            for i in range(n_makes):
                make=makes[i]
                models=d_make_models_trimed[make]
                n_models=len(d_make_models_trimed[make])
                if make=='VW': make = 'Volkswagen'
                if make=='Chevy': make = 'Chevrolet'
                if make=='Lexus':
                    regex_l=re.compile(r'\b([a-zA-Z]{2})(\d{3})\b',flags=re.IGNORECASE)
                    string_l=regex_l.sub(r'\1 \2',string)
                    for j in range(n_models):
                        if fuzz.token_set_ratio(models[j],string_l)>90:
                            make_return=make
                            model_return=models[j]
                            mk=1
                            mdl=1
                            break
                if make=='Ford':
                    regex_f=re.compile(r'\b(f)(\d{3})\b',flags=re.IGNORECASE)
                    string_f=regex_f.sub(r'\1-\2',string2)
                    for j in range(n_models):
                        if fuzz.token_set_ratio(models[j],string_f)>90:
                            make_return=make
                            model_return=models[j]
                            mk=1
                            mdl=1
                            break

                for j in range(n_models):
                    if fuzz.token_set_ratio(models[j],'pickup')>90: continue
                    if fuzz.token_set_ratio(models[j],string)>90:
                        make_return=make
                        model_return=models[j]
                        mk=1
                        mdl=1
                        break
        if mk==0:
            for i in range(n_makes):
                make=makes[i]
                models=d_make_models_trimed[make]
                n_models=len(d_make_models_trimed[make])
                if make=='VW': make = 'Volkswagen'
                if make=='Chevy': make = 'Chevrolet'
                if make=='Lexus':
                    regex_l=re.compile(r'\b([a-zA-Z]{2})(\d{3})\b',flags=re.IGNORECASE)
                    string_l2=regex_l.sub(r'\1 \2',string2)
                    for j in range(n_models):
                        if fuzz.token_set_ratio(models[j],string_l2)>90:
                            make_return=make
                            model_return=models[j]
                            mk=1
                            mdl=1
                            break
                if make=='Ford':
                    regex_f=re.compile(r'\b(f)(\d{3})\b',flags=re.IGNORECASE)
                    string_f2=regex_f.sub(r'\1-\2',string2)
                    for j in range(n_models):
                        if fuzz.token_set_ratio(models[j],string_f2)>90:
                            make_return=make
                            model_return=models[j]
                            mk=1
                            mdl=1
                            break

                for j in range(n_models):
                    if fuzz.token_set_ratio(models[j],'pickup')>90: continue
                    if fuzz.token_set_ratio(models[j],string2)>90:
                        make_return=make
                        model_return=models[j]
                        mk=1
                        mdl=1
                        break            
        
        return year_return, make_return, model_return
#        return model_return
    except:
        return None,None,None
#        return None

# %%
from fuzzywuzzy import fuzz
import re
def fill_all(string,string2):
    try:
        string=clean_up(string)
        string=clean_up(string2)        
        year_return=None        
        make_return=None
        model_return=None

        yr=0
        for word in re.split('\s|,|\-',string):
            try:
                if (int(word) <=2019) & (int(word) >= 1900):
                    yr=1
                    year_return=int(word)
                    break
            except:
                continue
        if yr==0:
            for word in re.split('\s|,|\-',string2):
                try:
                    if (int(word) <=2019) & (int(word) >= 1900):
                        year_return=int(word)
                        yr=1
                        break
                except:
                    continue
        mk=0
        mdl=0
        makes=list(d_make_models_trimed.keys())
        n_makes=len(makes)
        for i in range(n_makes):
            make=makes[i]
            if (make in string) or (make in string2):
                make_return=make
                mk=1
                models=d_make_models_trimed[make]
                n_models=len(d_make_models_trimed[make])
                for j in range(n_models):
                    if fuzz.token_set_ratio(models[j],string)>90:
                        model_return=models[j]
                        mdl=1
                        break
                if mdl==0:
                    for j in range(n_models):
                        if fuzz.token_set_ratio(models[j],string2)>90:
                            model_return=models[j]
                            mdl=1
                            break
                break
            if mk==0:
                if fuzz.token_set_ratio(make,string2)>90:
                    if make=='VW': make = 'Volkswagen'
                    if make=='Chevy': make = 'Chevrolet'
                    if make=='Lexus':
                        regex2=re.compile(r'\b([a-zA-Z]{2})(\d{3})\b',flags=re.IGNORECASE)
                        string=regex2.sub(r'\1 \2',string)
                        string2=regex2.sub(r'\1 \2',string2)
                    make_return=make
                    mk=1
                    models=d_make_models_trimed[make]
                    n_models=len(d_make_models_trimed[make])
                    for j in range(n_models):
                        if fuzz.token_set_ratio(models[j],string2)>90:
                            model_return=models[j]
                            mdl=1
                            break
                        if mdl==0:
                            for j in range(n_models):
                                if fuzz.token_set_ratio(models[j],string)>90:
                                    model_return=models[j]
                                    mdl=1
                                    break
                    break
                    
        if mk==0:
            for i in range(n_makes):
                make=makes[i]
                models=d_make_models_trimed[make]
                n_models=len(d_make_models_trimed[make])
                if make=='VW': make = 'Volkswagen'
                if make=='Chevy': make = 'Chevrolet'
                if make=='Lexus':
                    regex_l=re.compile(r'\b([a-zA-Z]{2})(\d{3})\b',flags=re.IGNORECASE)
                    string_l=regex_l.sub(r'\1 \2',string)
                    for j in range(n_models):
                        if fuzz.token_set_ratio(models[j],string_l)>90:
                            make_return=make
                            model_return=models[j]
                            mk=1
                            mdl=1
                            break
                if make=='Ford':
                    regex_f=re.compile(r'\b(f)(\d{3})\b',flags=re.IGNORECASE)
                    string_f=regex_f.sub(r'\1-\2',string2)
                    for j in range(n_models):
                        if fuzz.token_set_ratio(models[j],string_f)>90:
                            make_return=make
                            model_return=models[j]
                            mk=1
                            mdl=1
                            break

                for j in range(n_models):
                    if fuzz.token_set_ratio(models[j],'pickup')>90: continue
                    if fuzz.token_set_ratio(models[j],string)>90:
                        make_return=make
                        model_return=models[j]
                        mk=1
                        mdl=1
                        break
        if mk==0:
            for i in range(n_makes):
                make=makes[i]
                models=d_make_models_trimed[make]
                n_models=len(d_make_models_trimed[make])
                if make=='VW': make = 'Volkswagen'
                if make=='Chevy': make = 'Chevrolet'
                if make=='Lexus':
                    regex_l=re.compile(r'\b([a-zA-Z]{2})(\d{3})\b',flags=re.IGNORECASE)
                    string_l2=regex_l.sub(r'\1 \2',string2)
                    for j in range(n_models):
                        if fuzz.token_set_ratio(models[j],string_l2)>90:
                            make_return=make
                            model_return=models[j]
                            mk=1
                            mdl=1
                            break
                if make=='Ford':
                    regex_f=re.compile(r'\b(f)(\d{3})\b',flags=re.IGNORECASE)
                    string_f2=regex_f.sub(r'\1-\2',string2)
                    for j in range(n_models):
                        if fuzz.token_set_ratio(models[j],string_f2)>90:
                            make_return=make
                            model_return=models[j]
                            mk=1
                            mdl=1
                            break

                for j in range(n_models):
                    if fuzz.token_set_ratio(models[j],'pickup')>90: continue
                    if fuzz.token_set_ratio(models[j],string2)>90:
                        make_return=make
                        model_return=models[j]
                        mk=1
                        mdl=1
                        break            
        
        return year_return, make_return, model_return
#        return model_return
    except:
        return None,None,None
#        return None
def clean_up(string):
    if string==None: string=''
    string=re.sub(r'4runner',' 4-Runner ',string,flags=re.IGNORECASE)
    string=re.sub(r'rav-4|rav 4',' RAV4 ',string,flags=re.IGNORECASE)
    string=re.sub(r'toyota scion',' Scion ',string,flags=re.IGNORECASE)
    string=re.sub(r'\bchev\b|\bchevy\b',' Chevrolet ',string,flags=re.IGNORECASE)
    string=re.sub(r'\bvw\b',' Volkswagen ',string,flags=re.IGNORECASE)
    string=re.sub(' +', ' ',string)        
    string=string.strip(' ')

    
    regex1=re.compile(r'\bmercedes.*?benz\b|mercedes[^benz]|mercedes$',flags=re.IGNORECASE)
    if re.search(regex1, string) or re.search(regex1, string2):
        regex2=re.compile(r'\b([a-zA-Z]{1,3})(\d{2,3})\b',flags=re.IGNORECASE)
        string=regex2.sub(r'\1 \2',string)
        string2=regex2.sub(r'\1 \2',string2)
        string=re.sub(regex1, ' Mercedes-Benz ',string)
        string2=re.sub(regex1, ' Mercedes-Benz ',string2)

    regex3=re.compile(r'\bFord\b',flags=re.IGNORECASE)
    if re.search(regex3, string) or re.search(regex3, string2):
        regex4=re.compile(r'\b([a-zA-Z]{1})(\d{3})\b',flags=re.IGNORECASE)
        string=regex4.sub(r'\1-\2',string)
        string2=regex4.sub(r'\1-\2',string2)

    regex=re.compile(r'Mazda',flags=re.IGNORECASE)    
    if re.search(regex, string) or re.search(regex, string2):
        regex2=re.compile(r'(mazda).*?(\d{1})',flags=re.IGNORECASE)
        string=regex2.sub(r'mazda \1\2',string)
        string2=regex2.sub(r'mazda \1\2',string2)

                if make=='Lexus':
                    regex2=re.compile(r'\b([a-zA-Z]{2})(\d{3})\b',flags=re.IGNORECASE)
                    string=regex2.sub(r'\1 \2',string)
                    string2=regex2.sub(r'\1 \2',string2)

# %%
fill_all('2015 camaro','2015 camaro')
# Out:
# (2015, 'Chevrolet', 'Camaro')

# %%
df['model'][882608]
# Out:
# '2011 Chevy Cruz'

# %%
df['year0']=None
df['make0']=None
df['model0']=None
n=len(df['model'])
#df.insert(1, 'My 2nd new column', 'default value 2')
df.loc[0:n,['year0','make0','model0']]=list(map(fill_all, df['model'][0:n],df['Name'][0:n]))

# %%
from fuzzywuzzy import fuzz
import re
def fill_year(string,string2):
    try:
        if string==None: string=''
        if string2==None: string2=''
        string=re.sub(' +', ' ',string)        
        string=string.strip(' ')
        string2=re.sub(' +', ' ',string2)
        string2=string2.strip(' ')
        year_return=None        
        yr=0
        for word in re.split('\s|,|\-',string):
            try:
                if (int(word) <=2019) & (int(word) >= 1900):
                    yr=1
                    year_return=int(word)
                    break
            except:
                continue
        if yr==0:
            for word in re.split('\s|,|\-',string2):
                try:
                    if (int(word) <=2019) & (int(word) >= 1900):
                        year_return=int(word)
                        yr=1
                        break
                except:
                    continue
        
#        return year_return, make_return, model_return
        return year_return
    except:
#        return None,None,None
        return None
df['year0']=None
n=len(df['model'])
df.loc[0:n,['year0']]=list(map(fill_year, df['model'][0:n],df['Name'][0:n]))

# %%
#fix chevy / change function to one output before running
df.loc[df['make0']=='Chevrolet', ['year0','make0','model0']]=list(map(fill_all, df['model'][df['make0']=='Chevrolet'],df['Name'][df['make0']=='Chevrolet']))

# %%
#fix Toyota / change function to one output before running
df.loc[(df['make0']=='Toyota')&(df['model0'].isnull()), ['year0','make0','model0']]=list(map(fill_all, df['model'][(df['make0']=='Toyota')&(df['model0'].isnull())],df['Name'][(df['make0']=='Toyota')&(df['model0'].isnull())]))

# %%
#fix mazda
df.loc[(df['make0']=='Mazda')&(df['model0'].isnull()), ['year0','make0','model0']]=list(map(fill_all, df['model'][(df['make0']=='Mazda')&(df['model0'].isnull())],df['Name'][(df['make0']=='Mazda')&(df['model0'].isnull())]))

# %%
#fix MINI
df.loc[(df['make0']=='MINI'), ['year0','make0','model0']]=list(map(fill_all, df['model'][(df['make0']=='MINI')],df['Name'][(df['make0']=='MINI')]))

# %%
#fix chevy silverado
from fuzzywuzzy import fuzz
import re
def fill_silv(string,string2):
    try:
        if string==None: string=''
        if string2==None: string2=''
        string=string.title()
        string2=string2.title()
        regex1=re.compile(r'\b(\d{4})(hd)\b',flags=re.IGNORECASE)
        if re.search(regex1, string) or re.search(regex1, string2):
            string=regex1.sub(r'\1 \2',string)
            string2=regex1.sub(r'\1 \2',string2)
        string=re.sub(' +', ' ',string)        
        string=string.strip(' ')
        string2=re.sub(' +', ' ',string2)
        string2=string2.strip(' ')
        model_return=None
        mdl=0
        for word in re.split('\s|,|\-',string):
            try:
                if (int(word) ==1500) or (int(word) ==2500) or (int(word) ==3500):
                    model_return='Silverado'
                    mdl=1
                    break
            except:
                continue
        if mdl==0:
            for word in re.split('\s|,|\-',string2):
                try:
                    if (int(word) ==1500) or (int(word) ==2500) or (int(word) ==3500):
                        model_return='Silverado'
                        mdl=1
                        break
                except:
                    continue

        
#        return year_return, make_return, model_return
        return model_return
    except:
#        return None,None,None
        return None
df.loc[(df['make0']=='Chevrolet')&(df['model0'].isnull()), 'model0']=list(map(fill_silv, df['model'][(df['make0']=='Chevrolet')&(df['model0'].isnull())],df['Name'][(df['make0']=='Chevrolet')&(df['model0'].isnull())]))

# %%
#fix lexus / change function to one output before running
n=len(df['model0'][df['make0']=='Lexus'])
#df.insert(1, 'My 2nd new column', 'default value 2')
df.loc[df['make0']=='Lexus', 'model0']=list(map(fill_all, df['model'][df['make0']=='Lexus'],df['Name'][df['make0']=='Lexus']))

# %%
df.loc[df['make0'].isnull(), ['year0','make0','model0']]=list(map(fill_all, df['model'][df['make0'].isnull()],df['Name'][df['make0'].isnull()]))

# %%
df.loc[df['model0']=='3500', ['year0','make0','model0']]=list(map(fill_all, df['model'][(df['model0']=='3500')],df['Name'][(df['model0']=='3500')]))

# %%
df.loc[df['model0']=='Pickup', ['year0','make0','model0']]=list(map(fill_all, df['model'][(df['model0']=='Pickup')],df['Name'][(df['model0']=='Pickup')]))

# %%
import dill
dill.dump(df, open('data_df.pkd', 'wb'))
#df = dill.load(open('pandas_df_a_h.pkd', 'rb'))
#df.to_csv('table_a_h', sep=',', encoding='utf-8')

# %%
import dill
#dill.dump(df, open('pandas_df_a_h.pkd', 'wb'))
df = dill.load(open('data_df.pkd', 'rb'))
#df.to_csv('table_a_h', sep=',', encoding='utf-8')

# %%
df[['Name','model','year0','make0','model0']][(df['model0']=='Pickup')]
# Out:
# Empty DataFrame
# Columns: [Name, model, year0, make0, model0]
# Index: []

# %%
df[['Name','model','year0','make0','model0']][(df['make0']=='BMW')&(df['model0'].isnull())]
# Out:
#                                                      Name  \
# 3                                             2010 VW Bug
# 14                                          Toyota Camper
# 18                      2011 Ford Raptor SVT SUPERCHARGED
# 24                          classic1973CapriceConvertible
# 25                            Price Drop! 1952 Studebaker
# 53                                1987 Okanagan motorhome
# 94                                               2006 BMW
# 102                                   International Scout
# 103                1996 Chevy 2500 4x4 extended cab truck
# 117                                           2006 JAGUAR
# 121         2008 Lincoln Stretch Limousine Black On Black
# 133                                                  2013
# 177                     1995 CHEVY REG CAB ONE TON DUALLY
# 192               ford mercury capry reduced 4500 to 3000
# 246           1955 Chevy rare 210 2dr H.T. possible trade
# ...

# %%
# 5% for difference between listing and asking price
def price_fix(string):
    string=string.lstrip('$')
    return .95*(int(string))
df['Price'][0:len(df['Price'])]=list(map(price_fix, df['Price'][0:len(df['Price'])]))
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
import pandas as pd
import numpy as np
import dill
#df = dill.load(open('pandas_df_a_h.pkd', 'rb'))
X = df.dropna(axis=0, subset=['year0', 'odometer', 'make0','model0','Price'])
X['Car']=X['make0']+' '+X['model0']
#remove cars with low frequency
X=X[X.groupby('Car')['Car'].transform('count').ge(1000)]
X['year0'] = X['year0'].astype(int)
X['odometer'] = X['odometer'].astype(int)
X=X[X['year0']>1940][['year0','Car','odometer','Price','status']]
y = X[['Price']][:]
#X=np.asanyarray(X)
#y=np.asanyarray(y)
#X = pd.get_dummies(df=X)pd.get_dummies(s1, dummy_na=True)
#pd.isnull(X).sum() > 0

len(X)
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 714281

# %%
#no separation
import pandas as pd
import numpy as np
import dill
#df = dill.load(open('pandas_df_a_h.pkd', 'rb'))
X3 = df.dropna(axis=0, subset=['year0', 'odometer', 'make0','model0','Price'])
#remove cars with low frequency
X3=X3[[X3.groupby(['make0','model0'])[['make0','model0']].transform('count').ge(1000)][0]['make0']]
X3['year0'] = X3['year0'].astype(int)
X3['odometer'] = X3['odometer'].astype(int)
X3=X3[X3['year0']>1940][['year0','make0','model0','odometer','Price','status']]
y3 = X3[['Price']][:]
#X=np.asanyarray(X)
#y=np.asanyarray(y)
#X = pd.get_dummies(df=X)pd.get_dummies(s1, dummy_na=True)
#pd.isnull(X).sum() > 0

len(X3)
# Out:
# 714281

# %%
import random
boy=0
girl=0
for i in range(100000):
    while True:
        b=random.randint(0,1)
        if b==0:
            boy+=1
            break
        else:
            girl+=1
print(boy/(girl+boy))
# Out:
# 0.49986753510319765

# %%
# data colelction and preprocessing
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv
# for data visualisation and statistical analysis
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set_style("white")
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline

# %%
#viz
# here we set the figure size to 15x8
plt.figure(figsize=(15, 8))
# plot two values price per year_model
plt.scatter(X.year0,X.Price, alpha=0.1)
plt.xlabel("year built", fontsize=14)
plt.ylabel("price (USD)", fontsize=14)
plt.title("Scatter plot of price and year of model",fontsize=18)
plt.show()

# %%
#df.groupby(['make0', 'model0']).agg({'make0':'count'})
grouped = pd.pivot_table(X, values=['year0'], index=['Car'],aggfunc=len).reset_index()
grouped['Car'].sample(n=20)
# Out:
# 12         Chevrolet Suburban
# 44            Hyundai Elantra
# 35                 GMC Acadia
# 55          Nissan Pathfinder
# 59            Subaru Forester
# 70           Volkswagen Jetta
# 17    Chrysler Town & Country
# 38                  GMC Yukon
# 66                Toyota RAV4
# 33                Ford Ranger
# 43                Honda Pilot
# 15               Chrysler 200
# 61             Subaru Outback
# 19           Dodge Challenger
# 32               Ford Mustang
# 53              Nissan Maxima
# 68              Toyota Tacoma
# 6             Chevrolet Cruze
# 13            Chevrolet Tahoe
# 48                   Kia Soul
# Name: Car, dtype: object

# %%
grouped = pd.pivot_table(df[df['model0'].isnull()], values=['ID'], index=['make0'],aggfunc=len).reset_index()

# %%
grouped
# Out:
#             make0    ID
# 0      AM General   129
# 1           Acura    93
# 2      Alfa Romeo    60
# 3    Aston Martin    25
# 4            Audi   174
# 5             BMW  1632
# 6         Bentley    18
# 7         Bugatti     1
# 8           Buick   371
# 9        Cadillac   348
# 10      Chevrolet  4018
# 11       Chrysler   822
# 12          Dodge  1800
# 13        Ferrari    47
# 14           Fiat   229
# 15           Ford  3389
# 16            GMC  2029
# 17        Genesis  1450
# 18          Honda  1348
# 19         Hummer    28
# 20        Hyundai   264
# 21       Infiniti   941
# 22          Isuzu    86
# 23         Jaguar   469
# 24           Jeep   577
# 25            Kia   152
# 26    Lamborghini     5
# 27     Land Rover    79
# 28          Lexus   284
# 29        Lincoln   197
# 30           MINI   507
# 31       Maserati    41
# 32          Mazda   913
# 33        Mclaren     3
# 34  Mercedes-Benz  1165
# 35        Mercury   169
# 36         Nissan   803
# ...

# %%
#X[['year0','Car','odometer','Price']][(X['status']=='clean')&(X['year0']>2000)].dropna().sort_values(['Price'], ascending=[0]).head()
X1=X[['year0','Car','odometer','Price']][(X['status']=='clean')&(X['year0']>2000)].dropna()
X1.dtypes
# Out:
# year0         int64
# Car          object
# odometer      int64
# Price       float64
# dtype: object

# %%
import seaborn as sns
# %matplotlib inline

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(15, 10))
# Compute the correlation matrix
corr = X1.corr()
#print(corr)
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# Draw the heatmap with the mask and correct aspect ratio
ax=sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.7, center=0,
            square=True, linewidths=.9, cbar_kws={"shrink": .9,'label': 'corrolation'})
for _, spine in ax.spines.items():
    spine.set_visible(True)
plt.title('Correlation matrix', 
          fontsize = 20)
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 12))
sns.stripplot(data = X[(X['Car'].isin(grouped['Car'].sample(n=20)))&(X['status']=='clean')&(X['year0']>2000)], x='Price', y='Car', jitter=.1,color='blue',alpha=.1)
plt.xlabel("price (USD)", fontsize=14)
plt.ylabel("car model", fontsize=14)
plt.title("price range observation (20 samples)",fontsize=18)
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 10))
sns.violinplot(data = X, x='status', y='Price')

plt.xlabel("title status", fontsize=15)
plt.ylabel("car model", fontsize=15)
plt.title("violin plot (title status)",fontsize=18)
plt.show()

# %%
#dfg = df.groupby(['store', 'product']).agg({'sales': ['sum', 'count'], 'rating': 'mean'})
#df.groupby(['make0', 'model0']).size().unstack(level=1, fill_value=0)
#df.groupby(['make0', 'model0']).agg({'make0':'count'})
grouped = pd.pivot_table(X, values=['year0'], index=['Car'],aggfunc=len).reset_index()
grouped.sort_values(['year0'], ascending=[1]).head()
# Out:
#                   Car  year0
# 48           Kia Soul   1003
# 15       Chrysler 200   1011
# 55  Nissan Pathfinder   1012
# 49           Lexus RX   1032
# 53      Nissan Maxima   1038

# %%
#from sklearn.ensemble import GradientBoostingRegressor
# get an instance of the model, using ‘ls’ : least squares regression as a loss function and the default learning rate which 0.1
#gbr = GradientBoostingRegressor(loss ='ls', max_depth=6)
# fit the training data
#gbr.fit (X, Y)
# get the predicted values from the test set
#predicted = gbr.predict(X_test)
# extract the residual values
#residual = Y_test - predicted

# %%
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.pipeline import Pipeline
#from sklearn.feature_extraction import DictVectorizer
#from sklearn.linear_model import Ridge
#from sklearn.preprocessing import Imputer, PolynomialFeatures, StandardScaler, OneHotEncoder, MinMaxScaler
#from sklearn.neighbors import KNeighborsRegressor
#from sklearn.model_selection import GridSearchCV
#from sklearn.preprocessing import Imputer
#from sklearn.linear_model import LogisticRegression
#from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
#from sklearn.model_selection import GridSearchCV
#from sklearn.pipeline import Pipeline
#import numpy as np
ct_transformer = ColumnTransformer(
    [('oh_enc', OneHotEncoder(sparse=False), [1]),],  # the column numbers I want to apply this to
    remainder='passthrough'  # This leaves the rest of my columns in place
)
car_est=Pipeline([
    ('ct' , ct_transformer ),
    ('scl', StandardScaler()),
    ('gbr', GradientBoostingRegressor(loss ='ls', max_depth=6)),
])

car_est.fit(X1[['year0','Car','odometer']],X1[['Price']])

#ct.fit_transform(X.head())
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Pipeline(memory=None,
#      steps=[('ct', ColumnTransformer(n_jobs=None, remainder='passthrough', sparse_threshold=0.3,
#          transformer_weights=None,
#          transformers=[('oh_enc', OneHotEncoder(categorical_features=None, categories=None,
#        dtype=<class 'numpy.float64'>, handle_unknown='error',
#        n_values=Non...one, subsample=1.0, tol=0.0001,
#              validation_fraction=0.1, verbose=0, warm_start=False))])

# %%
car_est.score(X[['year0','Car','odometer']][X['status']=='clean'],y[X['status']=='clean'])

# %%
y_real=y[(X['status']=='clean')&(X['Car']=='Toyota Corolla')&(X['year0']==2014)]
y_predicted=car_est.predict(X[(X['status']=='clean')&(X['Car']=='Toyota Corolla')&(X['year0']==2014)])

# %%
#viz
# here we set the figure size to 15x8
plt.figure(figsize=(15, 8))
# plot two values price per year_model
plt.scatter(X1[(X1['Car']=='Toyota Corolla')&(X1['year0']==2014)].odometer, y_real, label="real")
plt.scatter(X1[(X1['Car']=='Toyota Corolla')&(X1['year0']==2014)].odometer, y_predicted, label="predicted")
#plt.plot(X[(X['status']=='clean')&(X['Car']=='Toyota Corolla')&(X['year0']==2014)].Miles,y_predicted, label="Predicted")
plt.xlabel("mileage", fontsize=17)
plt.ylabel("price (USD)", fontsize=17)
plt.title("Mileage observation - real price vs predicted (2014 Toyota Corolla)",fontsize=18)
plt.legend()
plt.show()

# %%
y_real=X1['Price'][(X1['Car']=='Toyota Corolla')&(X1['odometer']>=40000) &(X1['odometer']<=60000)]
y_predicted=car_est.predict(X1[(X1['Car']=='Toyota Corolla')&(X1['odometer']>=40000) &(X1['odometer']<=60000)])
#viz
# here we set the figure size to 15x8
plt.figure(figsize=(15, 8))

#plt.rcParams['figure.figsize'] = 16,5
# plot two values price per year_model
plt.scatter(X1[(X1['Car']=='Toyota Corolla')&(X1['odometer']>=40000) &(X1['odometer']<=60000)].year0, y_real, label="Real")
plt.scatter(X1[(X1['Car']=='Toyota Corolla')&(X1['odometer']>=40000) &(X1['odometer']<=60000)].year0, y_predicted, label="Predicted")
#plt.plot(X[(X['status']=='clean')&(X['Car']=='Toyota Corolla')&(X['year0']==2014)].Miles,y_predicted, label="Predicted")
plt.xlabel("year built", fontsize=17)
plt.ylabel("price (USD)", fontsize=17)
plt.title("model year observations - real price vs predicted (Toyota Corolla)",fontsize=18)
plt.legend()
plt.show()

# %%
#X[['year0','Car','odometer','Price']][(X['status']=='clean')&(X['year0']>2000)].dropna().sort_values(['Price'], ascending=[0]).head()
X4=X3[['year0','make0','model0','odometer','Price']][(X3['status']=='clean')&(X3['year0']>2000)].dropna()
X4.dtypes
# Out:
# year0         int64
# make0        object
# model0       object
# odometer      int64
# Price       float64
# dtype: object

# %%
#separate make model
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.pipeline import Pipeline
#from sklearn.feature_extraction import DictVectorizer
#from sklearn.linear_model import Ridge
#from sklearn.preprocessing import Imputer, PolynomialFeatures, StandardScaler, OneHotEncoder, MinMaxScaler
#from sklearn.neighbors import KNeighborsRegressor
#from sklearn.model_selection import GridSearchCV
#from sklearn.preprocessing import Imputer
#from sklearn.linear_model import LogisticRegression
#from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
#from sklearn.model_selection import GridSearchCV
#from sklearn.pipeline import Pipeline
#import numpy as np
ct_transformer = ColumnTransformer(
    [('oh_enc', OneHotEncoder(sparse=False), [1,2]),],  # the column numbers I want to apply this to
    remainder='passthrough'  # This leaves the rest of my columns in place
)
car_est=Pipeline([
    ('ct' , ct_transformer ),
    ('scl', StandardScaler()),
    ('gbr', GradientBoostingRegressor(loss ='ls', max_depth=6)),
])

car_est.fit(X4[['year0','make0','model0','odometer']],X4[['Price']])

#ct.fit_transform(X.head())
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Pipeline(memory=None,
#      steps=[('ct', ColumnTransformer(n_jobs=None, remainder='passthrough', sparse_threshold=0.3,
#          transformer_weights=None,
#          transformers=[('oh_enc', OneHotEncoder(categorical_features=None, categories=None,
#        dtype=<class 'numpy.float64'>, handle_unknown='error',
#        n_values=Non...one, subsample=1.0, tol=0.0001,
#              validation_fraction=0.1, verbose=0, warm_start=False))])

# %%
car_est.score(X4[['year0','make0','model0','odometer']],X4['Price'])
# Out:
# 0.8170683140999258

# %%
y_real=X4['Price'][(X4['make0']=='Toyota')&(X4['model0']=='Corolla')&(X4['year0']==2014)]
y_predicted=car_est.predict(X4[(X4['make0']=='Toyota')&(X4['model0']=='Corolla')&(X4['year0']==2014)])

# %%
#viz
# here we set the figure size to 15x8
plt.figure(figsize=(15, 8))
# plot two values price per year_model
plt.scatter(X4[(X4['make0']=='Toyota')&(X4['model0']=='Corolla')&(X4['year0']==2014)].odometer, y_real, label="real")
plt.scatter(X4[(X4['make0']=='Toyota')&(X4['model0']=='Corolla')&(X4['year0']==2014)].odometer, y_predicted, label="predicted")
#plt.plot(X[(X['status']=='clean')&(X['Car']=='Toyota Corolla')&(X['year0']==2014)].Miles,y_predicted, label="Predicted")
plt.xlabel("mileage", fontsize=17)
plt.ylabel("price (USD)", fontsize=17)
plt.title("Mileage observation - real price vs predicted (2014 Toyota Corolla)",fontsize=18)
plt.legend()
plt.show()

# %%
y_real=X4['Price'][(X4['make0']=='Toyota')&(X4['model0']=='Corolla')&(X1['odometer']>=40000) &(X4['odometer']<=60000)]
y_predicted=car_est.predict(X4[(X4['make0']=='Toyota')&(X4['model0']=='Corolla')&(X4['odometer']>=40000) &(X4['odometer']<=60000)])
#viz
# here we set the figure size to 15x8
plt.figure(figsize=(15, 8))

#plt.rcParams['figure.figsize'] = 16,5
# plot two values price per year_model
plt.scatter(X4[(X4['make0']=='Toyota')&(X4['model0']=='Corolla')&(X4['odometer']>=40000) &(X4['odometer']<=60000)].year0, y_real, label="real")
plt.scatter(X4[(X4['make0']=='Toyota')&(X4['model0']=='Corolla')&(X4['odometer']>=40000) &(X4['odometer']<=60000)].year0, y_predicted, label="predicted")
#plt.plot(X[(X['status']=='clean')&(X['Car']=='Toyota Corolla')&(X['year0']==2014)].Miles,y_predicted, label="Predicted")
plt.xlabel("year built", fontsize=17)
plt.ylabel("price (USD)", fontsize=17)
plt.title("model year observations - real price vs predicted (Toyota Corolla)",fontsize=18)
plt.legend()
plt.show()

# %%
#cross validation
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn import metrics

X_train, X_test, y_train, y_test = train_test_split(X4[['year0','make0','model0','odometer']],X4[['Price']], test_size=0.2, random_state=42,shuffle=True)

ct_transformer = ColumnTransformer(
    [('oh_enc', OneHotEncoder(sparse=False), [1,2]),],  # the column numbers I want to apply this to
    remainder='passthrough'  # This leaves the rest of my columns in place
)
car_est=Pipeline([
    ('ct' , ct_transformer ),
    ('scl', StandardScaler()),
    ('gbr', GradientBoostingRegressor(loss ='ls', max_depth=6)),
])

car_est.fit (X_train, y_train)
predicted = car_est.predict(X_test)
residual = y_test['Price'] - predicted

fig = plt.figure(figsize=(30,30))
ax1 = plt.subplot(211)
sns.distplot(residual, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.title('Residual counts',fontsize=35)
plt.xlabel('Residual',fontsize=25)
plt.ylabel('Count',fontsize=25)

ax2 = plt.subplot(212)
plt.scatter(predicted, residual, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Predicted',fontsize=25)
plt.ylabel('Residual',fontsize=25)
plt.axhline(y=0)
plt.title('Residual vs. Predicted',fontsize=35)

plt.show()
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
fig = plt.figure(figsize=(30,30))
ax2 = plt.subplot(212)
plt.scatter(predicted, np.asanyarray(residual)/predicted, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Predicted',fontsize=25)
plt.ylabel('Residual/Predicted',fontsize=25)
plt.axhline(y=0)
plt.title('Residual vs. Predicted',fontsize=35)

plt.show()

# %%
np.asanyarray(residual)
# Out:
# array([-4115.20069701,  -374.98843442, -3279.4889696 , ...,
#        -6008.43149472, -1089.59961165, -2349.09950284])

# %%
rmse = np.sqrt(mean_squared_error(y_test, predicted))
scores = cross_val_score(car_est, X4[['year0','make0','model0','odometer']],X4['Price'], cv=12)

print('\nCross Validation Scores:')
print(scores)
print('\nMean Score:')
print(scores.mean())
print('\nRMSE:')
print(rmse)

#car_est.fit(X_train, y_train)
#pred=car_est.predict(X_test)
#score = -cross_val_score(car_est, X_test, y_test,cv=10, scoring='neg_mean_squared_error').mean()
#print(score)

# %%
from sklearn.metrics import mean_squared_error
residual = y_test['Price'] - predicted

fig = plt.figure(figsize=(30,30))
ax1 = plt.subplot(211)
sns.distplot(residual, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.title('Residual counts',fontsize=35)
plt.xlabel('Residual',fontsize=25)
plt.ylabel('Count',fontsize=25)

ax2 = plt.subplot(212)
plt.scatter(predicted, residual, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Predicted',fontsize=25)
plt.ylabel('Residual',fontsize=25)
plt.axhline(y=0)
plt.title('Residual vs. Predicted',fontsize=35)

plt.show()

rmse = np.sqrt(mean_squared_error(y_test, predicted))
scores = cross_val_score(car_est, X4[['year0','make0','model0','odometer']],X4['Price'], cv=12)

print('\nCross Validation Scores:')
print(scores)
print('\nMean Score:')
print(scores.mean())
print('\nRMSE:')
print(rmse)

#car_est.fit(X_train, y_train)
#pred=car_est.predict(X_test)
#score = -cross_val_score(car_est, X_test, y_test,cv=10, scoring='neg_mean_squared_error').mean()
#print(score)
# Out:
# Cross Validation Scores:
# [0.81984112 0.80512939 0.79576347 0.80716518 0.80335399 0.81817161
#  0.78322116 0.79951559 0.82980745 0.79907459 0.8201084  0.80059822]
#
# Mean Score:
# 0.8068125126675119
#
# RMSE:
# 3974.902501873213

# %%
score = -cross_val_score(car_est, X_test, y_test,cv=10, scoring='neg_mean_squared_error').mean()
print(score)
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
#from sklearn.feature_extraction import DictVectorizer
#from sklearn.linear_model import Ridge
#from sklearn.preprocessing import Imputer, PolynomialFeatures, StandardScaler, OneHotEncoder, MinMaxScaler
#from sklearn.neighbors import KNeighborsRegressor
#from sklearn.model_selection import GridSearchCV
#from sklearn.preprocessing import Imputer
#from sklearn.linear_model import LogisticRegression
#from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(X[['year0','Car','Miles']],y, test_size=0.2, random_state=42,shuffle=True)
ct_transformer = ColumnTransformer(
    [('oh_enc', OneHotEncoder(sparse=False), [1]),],  # the column numbers I want to apply this to
    remainder='passthrough'  # This leaves the rest of my columns in place
)
car_est=Pipeline([
    ('ct' , ct_transformer ),
    ('scl', StandardScaler()),
    ('gbr', GradientBoostingRegressor(loss ='ls', max_depth=6)),
])
car_est.fit (X_train, y_train)
predicted = car_est.predict(X_test)
residual = y_test - predicted

fig = plt.figure(figsize=(30,30))
ax1 = plt.subplot(211)
sns.distplot(residual, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.title('Residual counts',fontsize=35)
plt.xlabel('Residual',fontsize=25)
plt.ylabel('Count',fontsize=25)

ax2 = plt.subplot(212)
plt.scatter(predicted, residual, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Predicted',fontsize=25)
plt.ylabel('Residual',fontsize=25)
plt.axhline(y=0)
plt.title('Residual vs. Predicted',fontsize=35)

plt.show()

rmse = np.sqrt(mean_squared_error(y_test, predicted))
scores = cross_val_score(car_est, [['year0','Car','Miles']], y, cv=12)

print('\nCross Validation Scores:')
print(scores)
print('\nMean Score:')
print(scores.mean())
print('\nRMSE:')
print(rmse)
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-12f1621b9967> in <module>()
#      30 car_est.fit (X_train, y_train)
#      31 predicted = car_est.predict(X_test)
# ---> 32 residual = y_test - predicted
#      33
#      34 fig = plt.figure(figsize=(30,30))
#
# /opt/conda/envs/data3/lib/python3.6/site-packages/pandas/core/ops.py in f(self, other, axis, level, fill_value)
#    1545     def f(self, other, axis=default_axis, level=None, fill_value=None):
#    1546
# -> 1547         other = _align_method_FRAME(self, other, axis)
#    1548
# ...

# %%
np.asanyarray(y_test) - predicted

# %%
print('Variance score: %.2f' % r2_score(y_test, predicted))

# %%
from sklearn.metrics import r2_score
r2_score(y.head(), car_est.predict(X.head()))
# Out:
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 0.9253051556480631

# %%
X
# Out:
# array([[0., 1., 2., 2.],
#        [1., 1., 0., 1.]])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import Normalizer
import numpy as np
ct = ColumnTransformer([("norm1", Normalizer(norm='l1'), [0, 1]),
                        ("norm2", Normalizer(norm='l1'), slice(2, 4))])
X = np.array([[0., 1., 2., 2.],
              [1., 1., 0., 1.]])
# Normalizer scales each row of X to unit norm. A separate scaling
# is applied for the two first and two last elements of each

# row independently.
ct.fit_transform(X)
# Out:
# array([[0. , 1. , 0.5, 0.5],
#        [0.5, 0.5, 0. , 1. ]])

# %%
np.asanyarray(y)
# Out:
# array([[42500],
#        [16250],
#        [15000],
#        ...,
#        [ 6994],
#        [ 3400],
#        [ 6991]])
